# %% [markdown]
# # Tabular-playground-series-mar-2022
#
# In this competition, you'll forecast twelve-hours of traffic flow in a major U.S. metropolitan area. Time, space, and directional features give you the chance to model interactions across a network of roadways.
#
# `Regression` task:
# Metric is `mean absolute error`.
#
# For each `row_id` in the test set, you should predict a `congestion` measurement.
#
# 1. `train.csv` - the training set, comprising measurements of traffic congestion across 65 roadways from April through September of 1991.
# * `row_id` - a unique identifier for this instance
# * `time` - the 20-minute period in which each measurement was taken
# * `x` - the east-west midpoint coordinate of the roadway
# * `y` - the north-south midpoint coordinate of the roadway
# * `direction` - the direction of travel of the roadway. EB indicates "eastbound" travel, for example, while SW indicates a "southwest" direction of travel.
# * `congestion` - congestion levels for the roadway during each hour; the target. The congestion measurements have been normalized to the range 0 to 100.
# 2. `test.csv` - the test set; you will make hourly predictions for roadways identified by a coordinate location and a direction of travel on the day of 1991-09-30.
# 3. `sample_submission.csv` - a sample submission file in the correct format

# %%
# Import all the tools
import warnings
from tqdm import tqdm_notebook
import seaborn as sns
from plotly.offline import init_notebook_mode
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.express as px
import os  # access to folder
from os import path
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import accuracy_score
# from sklearn.impute import IterativeImputer
warnings.filterwarnings("ignore")

cwd = os.getcwd()
cwd = cwd.replace('\\','/')

train = pd.read_csv(cwd + "/tabular-playground-series-mar-2022/train.csv")
test = pd.read_csv(cwd + "/tabular-playground-series-mar-2022/test.csv")
sub = pd.read_csv(cwd + "/tabular-playground-series-mar-2022/sample_submission.csv")

# plots inside the notebook
# %matplotlib inline
print('Train Shape: {}\nMissing Data: {}\nDuplicates: {}\nMemory usage: {}\n'.format(
    train.shape, train.isna().sum().sum(), train.duplicated().sum(), np.around(train.memory_usage().sum() / 1024**2), 2))
print('Test Shape: {}\nMissing Data: {}\nDuplicates: {}\nMemory usage: {}\n'.format(
    test.shape, test.isna().sum().sum(), test.duplicated().sum(), np.around(test.memory_usage().sum() / 1024**2, 3)))

# remove duplicates from train
train_d = train.drop_duplicates()

if train.shape == train_d.shape:
    print('No duplicates')
else:
    print('Dropping Duplicates\nNew Train Shape: {}'.format(train_d.shape))
    
df_data = pd.concat([train_d, test])
# Out:
# Train Shape: (848835, 6)
# Missing Data: 0
# Duplicates: 0
# Memory usage: 39.0
#
# Test Shape: (2340, 5)
# Missing Data: 0
# Duplicates: 0
# Memory usage: 0.089
#
# No duplicates

# %%
train.head(2)
# Out:
#    row_id                 time  x  y direction  congestion
# 0       0  1991-04-01 00:00:00  0  0        EB          70
# 1       1  1991-04-01 00:00:00  0  0        NB          49

# %%
test.head(2)
# Out:
#    row_id                 time  x  y direction
# 0  848835  1991-09-30 12:00:00  0  0        EB
# 1  848836  1991-09-30 12:00:00  0  0        NB

# %%
sub.head(2)
# Out:
#    row_id  congestion
# 0  848835         0.0
# 1  848836         0.0

# %% [markdown]
# No missing data, No duplicates, data has not shuffled

# %%
def reduce_mem_usage(df, verbose=True):
    numerics = ['int8','int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2

    for col in df.columns:
        col_type = df[col].dtypes

        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()

            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)

    end_mem = df.memory_usage().sum() / 1024**2

    if verbose:
        print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
 
    return df

# %% [markdown]
# # EDA

# %% [markdown]
# ## Target

# %%
train['congestion'].describe()
# Out:
# count    848835.000000
# mean         47.815305
# std          16.799392
# min           0.000000
# 25%          35.000000
# 50%          47.000000
# 75%          60.000000
# max         100.000000
# Name: congestion, dtype: float64

# %%
train['congestion'].hist(bins=100); # target value is normally distributed, but some outliers by the amount of observations

# %% [markdown]
# ## X_train

# %%
train.dtypes
# Out:
# row_id         int64
# time          object
# x              int64
# y              int64
# direction     object
# congestion     int64
# dtype: object

# %%
train.describe()
# Out:
#              row_id              x              y     congestion
# count  848835.00000  848835.000000  848835.000000  848835.000000
# mean   424417.00000       1.138462       1.630769      47.815305
# std    245037.70221       0.801478       1.089379      16.799392
# min         0.00000       0.000000       0.000000       0.000000
# 25%    212208.50000       0.000000       1.000000      35.000000
# 50%    424417.00000       1.000000       2.000000      47.000000
# 75%    636625.50000       2.000000       3.000000      60.000000
# max    848834.00000       2.000000       3.000000     100.000000

# %%
sns.boxplot(data=train);

# %%
# df_data['time'] = pd.to_datetime(df_data['time'], format='%Y-%m-%d %H:%M:%S')
# df_data['year'] = df_data.time.dt.year
# df_data['month'] = df_data.time.dt.month
# df_data['week'] = df_data.time.dt.isocalendar().week
# df_data['hour'] = df_data.time.dt.hour
# df_data['minute'] = df_data.time.dt.minute
# df_data['day_of_week'] = df_data.time.dt.day_name()
# df_data['day_of_year'] = df_data.time.dt.dayofyear
# df_data['is_weekend'] = (df_data.time.dt.dayofweek >= 5).astype("int")

# df_data.drop('time', axis=1, inplace=True)

# %%
# from itertools import cycle
# from plotly.subplots import make_subplots

# palette = cycle(px.colors.sequential.Sunsetdark)
# df_graph = df_data[df_data['congestion'].isnull() == False]

# # chart
# fig = make_subplots(rows=2, cols=3, 
#                     specs=[[{"type": "scatter"}, {"type": "scatter"}, {'type':'scatter'}], [{"type": "scatter"}, {"type": "scatter"}, {'type':'scatter'}]],
#                     column_widths=[0.33, 0.33, 0.34], vertical_spacing=0.125, horizontal_spacing=0.1,
#                     subplot_titles=("Monday Congestion", "Tuesday Congestion", "Wednesday Congestion",'Thursday Congestion','Friday Congestion','Weekend Congestion'))

# # Upper Left chart
# df_monday = df_graph[df_graph.day_of_week == 'Monday'].groupby(['hour']).agg({"congestion" : "mean"}).reset_index()
# fig.add_trace(go.Scatter(x=df_monday['hour'], y=df_monday['congestion'], mode='lines+markers',
#                  marker = dict(color = next(palette)), name='Monday Congestion'), row = 1, col = 1)

# fig.update_xaxes(showgrid = False, linecolor='gray', linewidth = 2, zeroline = False, row=1, col=1)
# fig.update_yaxes(gridcolor = 'gray', gridwidth = 0.5, linecolor='gray',linewidth=2, row=1, col=1)

# # Upper Medium chart
# df_tuesday = df_graph[df_graph.day_of_week == 'Tuesday'].groupby(['hour']).agg({"congestion" : "mean"}).reset_index()
# fig.add_trace(go.Scatter(x=df_tuesday['hour'], y=df_tuesday['congestion'], mode='lines+markers',
#                  marker = dict(color = next(palette)), name='Monday Congestion'), row = 1, col = 2)

# fig.update_xaxes(showgrid = False, linecolor='gray', linewidth = 2, zeroline = False, row=1, col=2)
# fig.update_yaxes(gridcolor = 'gray', gridwidth = 0.5, linecolor='gray',linewidth=2, row=1, col=2)

# # Upper Right chart
# df_wednesday = df_graph[df_graph.day_of_week == 'Wednesday'].groupby(['hour']).agg({"congestion" : "mean"}).reset_index()
# fig.add_trace(go.Scatter(x=df_wednesday['hour'], y=df_wednesday['congestion'], mode='lines+markers',
#                  marker = dict(color = next(palette)), name='Monday Congestion'), row = 1, col = 3)

# fig.update_xaxes(showgrid = False, linecolor='gray', linewidth = 2, zeroline = False, row=1, col=3)
# fig.update_yaxes(gridcolor = 'gray', gridwidth = 0.5, linecolor='gray',linewidth=2, row=1, col=3)

# # Bottom Left chart
# df_thursday = df_graph[df_graph.day_of_week == 'Thursday'].groupby(['hour']).agg({"congestion" : "mean"}).reset_index()
# fig.add_trace(go.Scatter(x=df_thursday['hour'], y=df_thursday['congestion'], mode='lines+markers',
#                  marker = dict(color = next(palette)), name='Monday Congestion'), row = 2, col = 1)

# fig.update_xaxes(showgrid = False, linecolor='gray', linewidth = 2, zeroline = False, row=2, col=1)
# fig.update_yaxes(gridcolor = 'gray', gridwidth = 0.5, linecolor='gray',linewidth=2, row=2, col=1)

# # Bottom Medium chart
# df_friday = df_graph[df_graph.day_of_week == 'Friday'].groupby(['hour']).agg({"congestion" : "mean"}).reset_index()
# fig.add_trace(go.Scatter(x=df_friday['hour'], y=df_friday['congestion'], mode='lines+markers',
#                  marker = dict(color = next(palette)), name='Monday Congestion'), row = 2, col = 2)

# fig.update_xaxes(showgrid = False, linecolor='gray', linewidth = 2, zeroline = False, row=2, col=2)
# fig.update_yaxes(gridcolor = 'gray', gridwidth = 0.5, linecolor='gray',linewidth=2, row=2, col=2)

# # Bottom Right chart
# df_weekend = df_graph[df_graph.is_weekend == True].groupby(['hour']).agg({"congestion" : "mean"}).reset_index()
# df_saturday = df_graph[df_graph.day_of_week == 'Saturday'].groupby(['hour']).agg({"congestion" : "mean"}).reset_index()
# df_sunday = df_graph[df_graph.day_of_week == 'Sunday'].groupby(['hour']).agg({"congestion" : "mean"}).reset_index()

# fig.add_trace(go.Scatter(x=df_weekend['hour'], y=df_weekend['congestion'], mode='lines+markers',
#                  marker = dict(color = next(palette)), name='Weekend Average Congestion'), row = 2, col = 3)
# fig.add_trace(go.Scatter(x=df_saturday['hour'], y=df_saturday['congestion'], mode='lines+markers',
#                  marker = dict(color = next(palette)), name='Saturday Congestion'), row = 2, col = 3)
# fig.add_trace(go.Scatter(x=df_sunday['hour'], y=df_sunday['congestion'], mode='lines+markers',
#                  marker = dict(color = next(palette)), name='Sunday Congestion'), row = 2, col = 3)

# fig.update_xaxes(showgrid = False, linecolor='gray', linewidth = 2, zeroline = False, row=2, col=3)
# fig.update_yaxes(gridcolor = 'gray', gridwidth = 0.5, linecolor='gray',linewidth=2, row=2, col=3)

# # General Styling
# fig.update_layout(height=750, bargap=0.2,
#                   margin=dict(b=50,r=30,l=100),
#                   title_text="Day of Week Congestion Analysis",
#                   #template="plotly_dark",
#                   paper_bgcolor="#303330",
#                   plot_bgcolor = "#303330",
#                   title_font=dict(size=29, color='floralwhite', family="Lato, sans-serif"),
#                   font=dict(color='floralwhite'), 
#                   hoverlabel=dict(bgcolor="floralwhite", font_size=13, font_family="Lato, sans-serif"),
#                   showlegend=False)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# palette = cycle(px.colors.sequential.Sunsetdark)
# df_graph = df_data[df_data['congestion'].isnull() == False]

# # chart
# fig = make_subplots(rows=1, cols=3, 
#                     specs=[[{"type": "bar"}, {"type": "bar"}, {'type':'bar'}]],
#                     column_widths=[0.33, 0.34, 0.33], vertical_spacing=0.1, horizontal_spacing=0.1,
#                     subplot_titles=("Mean Congestion per Direction", "Mean Congestion Per X Location", "Mean Congestion per Y Location"))

# # Left chart
# df_direction = df_graph.groupby(['direction']).agg({"congestion" : "mean"})
# values = list(range(8))
# fig.add_trace(go.Bar(x=df_direction.index, y=df_direction['congestion'], marker = dict(color=values, colorscale="Sunsetdark"), name = 'Day of Week'),
#                       row=1, col=1)

# fig.update_xaxes(showgrid = False, linecolor='gray', linewidth = 2, zeroline = False, row=1, col=1)
# fig.update_yaxes(showgrid = False, linecolor='gray',linewidth=2, zeroline = False, row=1, col=1)

# # Middle chart
# df_x = df_graph.groupby(['x']).agg({"congestion" : "mean"})
# values = list(range(3))
# fig.add_trace(go.Bar(x=df_x.index, y=df_x['congestion'], marker = dict(color=values, colorscale="Sunsetdark"), name = 'Day of Week'),
#                       row=1, col=2)

# fig.update_xaxes(showgrid = False, linecolor='gray', linewidth = 2, zeroline = False, row=1, col=2)
# fig.update_yaxes(showgrid = False, linecolor='gray',linewidth=2, zeroline = False, row=1, col=2)

# # Right chart
# df_y = df_graph.groupby(['y']).agg({"congestion" : "mean"})
# values = list(range(4))
# fig.add_trace(go.Bar(x=df_y.index, y=df_y['congestion'], marker = dict(color=values, colorscale="Sunsetdark"), name = 'Day of Week'),
#                       row=1, col=3)

# fig.update_xaxes(showgrid = False, linecolor='gray', linewidth = 2, zeroline = False, row=1, col=3)
# fig.update_yaxes(showgrid = False, linecolor='gray',linewidth=2, zeroline = False, row=1, col=3)

# # General Styling
# fig.update_layout(height=400, bargap=0.2,
#                   margin=dict(b=50,r=30,l=100),
#                   title_text="Direction and Location Analysis",
#                   #template="plotly_dark",
#                   paper_bgcolor="#303330",
#                   plot_bgcolor = "#303330",
#                   title_font=dict(size=29, color='floralwhite', family="Lato, sans-serif"),
#                   font=dict(color='floralwhite'), 
#                   hoverlabel=dict(bgcolor="floralwhite", font_size=13, font_family="Lato, sans-serif"),
#                   showlegend=False)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Outliers

# %% [markdown]
# Outlier is an observation that is numerically distant from the rest of the data or in a simple word it is the value which is out of the range.let’s take an example to check what happens to a data set with and data set without outliers.

# %% [markdown]
# **Grubbs Test:**

# %% [markdown]
# Grubbs' test is defined for the hypothesis: `Ho`: **There are no outliers in the data set**
# `H1`: **There is exactly one outlier in the data set**

# %%
# import scipy.stats as stats
# def grubbs_test(x):
#     n = len(x)
#     mean_x = np.mean(x)
#     sd_x = np.std(x)
#     numerator = max(abs(x-mean_x))
#     g_calculated = numerator/sd_x
#     print("Grubbs Calculated Value:",g_calculated)
#     t_value = stats.t.ppf(1 - 0.05 / (2 * n), n - 2)
#     g_critical = ((n - 1) * np.sqrt(np.square(t_value))) / (np.sqrt(n) * np.sqrt(n - 2 + np.square(t_value)))
#     print("Grubbs Critical Value:",g_critical)
#     if g_critical > g_calculated:
#         print("From grubbs_test we observe that calculated value is lesser than critical value, Accept null hypothesis and conclude that there is no outliers\n")
#     else:
#         print("From grubbs_test we observe that calculated value is greater than critical value, Reject null hypothesis and conclude that there is an outliers\n")

# grubbs_test(df_data[df_data.congestion.isnull() == False]['congestion'])

# %% [markdown]
# **Z-score:**

# %%
# df_outlier = df_data.reset_index().set_index('row_id').copy()
# out=[]
# def Zscore_outlier(df):
#     m = np.mean(df)
#     sd = np.std(df)
#     row = 0
#     for i in df: 
#         z = (i-m)/sd
#         if np.abs(z) > 3: 
#             out.append(row)
#         row += 1
#     return out

# outliers_index = Zscore_outlier(df_outlier[df_outlier.congestion.isnull() == False]['congestion'])

# %%
# df_outlier['outlier'] = 0
# df_outlier.loc[outliers_index,'outlier'] = 1

# fig = px.scatter(df_outlier, x=df_outlier.index, y='congestion', color = 'outlier')
# fig.update_xaxes(visible = False, zeroline = False)
# fig.update_yaxes(showgrid = True, gridcolor = 'gray', gridwidth = .5, zeroline = False)

# fig.update_layout(height=400,
#                   margin=dict(b=20,r=20,l=20,t=70),
#                   title_text="Congestion Outliers Analysis",
#                   paper_bgcolor="#303330",
#                   plot_bgcolor = "#303330",
#                   title_font=dict(size=29, color='floralwhite', family="Lato, sans-serif"),
#                   font=dict(color='floralwhite'), 
#                   hoverlabel=dict(bgcolor="floralwhite", font_size=13, font_family="Lato, sans-serif"))

# %% [markdown]
# # Baseline

# %% [markdown]
# **1-st baseline = -7.21775 MAE**

# %%
def baseline(X, y):
    from sklearn.model_selection import cross_val_score
    X = reduce_mem_usage(X)
    model = RandomForestRegressor()
    cv = cross_val_score(
        model, X, y, cv=5, scoring="neg_mean_absolute_error", n_jobs=-1
    )
    score = cv.mean()
    print(f"Baseline score: {score:.5f} MAE")
    return score
    


train_base = df_data[df_data.congestion.isnull() == False].copy()
train_base['time'] = pd.to_datetime(train_base['time'], format='%Y-%m-%d %H:%M:%S')
train_base['year'] = train_base.time.dt.year
train_base['month'] = train_base.time.dt.month
train_base['week'] = train_base.time.dt.isocalendar().week
train_base['hour'] = train_base.time.dt.hour
train_base['minute'] = train_base.time.dt.minute
train_base['day_of_week'] = train_base.time.dt.day_name()
train_base['day_of_year'] = train_base.time.dt.dayofyear
train_base['is_weekend'] = (train_base.time.dt.dayofweek >= 5).astype("int")
train_base.drop('time', axis=1, inplace=True)


train_base.drop('row_id', axis=1, inplace=True)
train_base.drop('year', axis=1, inplace=True)
train_base['direction'] = train_base['direction'].map({'EB': 0, 'NB': 1, 'SB': 2, 'WB': 3, 'NE': 4, 'SW': 5, 'NW': 6, 'SE': 7})
train_base['day_of_week'] = train_base['day_of_week'].map({'Monday': 0, 'Tuesday': 1, 'Wednesday': 2, 'Thursday': 3, 'Friday': 4, 'Saturday': 5, 'Sunday': 6})
# y = train_base['congestion']
# X = train_base.drop('congestion', axis=1)

# baseline_score = baseline(train_base.drop('congestion', axis=1), train_base['congestion'])
# print(f"Baseline score: {baseline_score:.5f} MAE")

# %%
# from pycaret.regression import *

# train_base.drop('week', axis=1, inplace=True)

# s = setup(data = train_base,
#           target = 'congestion',
#           fold = 2,
#           fold_shuffle = True)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# best_model = compare_models(exclude=['knn'])

# %% [markdown]
# # FE

# %%
stop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [68], in <cell line: 1>()
# ----> 1 stop
#
# NameError: name 'stop' is not defined

# %%
# remove row_id and year(the same year for train & test)
df_data['time'] = pd.to_datetime(df_data['time'], format='%Y-%m-%d %H:%M:%S')
df_data['year'] = df_data.time.dt.year
df_data['month'] = df_data.time.dt.month
df_data['week'] = df_data.time.dt.isocalendar().week
df_data['hour'] = df_data.time.dt.hour
df_data['minute'] = df_data.time.dt.minute
df_data['day_of_week'] = df_data.time.dt.day_name()
df_data['day_of_year'] = df_data.time.dt.dayofyear
df_data['is_weekend'] = (df_data.time.dt.dayofweek >= 5).astype("int")
df_data['is_month_start'] = df_data['time'].dt.is_month_start.astype('int')
df_data['is_month_end'] = df_data['time'].dt.is_month_end.astype('int')
df_data['hour+minute'] = df_data['time'].dt.hour * 60 + df_data['time'].dt.minute
df_data['is_weekend'] = (df_data['time'].dt.dayofweek > 4).astype('int')
df_data['is_afternoon'] = (df_data['time'].dt.hour > 12).astype('int')

df_data.drop('time', axis=1, inplace=True)
df_data.drop('row_id', axis=1, inplace=True)
df_data.drop('year', axis=1, inplace=True)
df_data.drop('week', axis=1, inplace=True)
df_data.drop('day_of_week', axis=1, inplace=True)

df_data['x+y'] = df_data['x'].astype('str') + df_data['y'].astype('str')
df_data['x+y+direction'] = df_data['x'].astype('str') + df_data['y'].astype('str') + df_data['direction'].astype('str')
df_data['hour+direction'] = df_data['hour'].astype('str') + df_data['direction'].astype('str')
df_data['hour+x+y'] = df_data['hour'].astype('str') + df_data['x'].astype('str') + df_data['y'].astype('str')
df_data['hour+direction+x'] = df_data['hour'].astype('str') + df_data['direction'].astype('str') + df_data['x'].astype('str')
df_data['hour+direction+y'] = df_data['hour'].astype('str') + df_data['direction'].astype('str') + df_data['y'].astype('str')
df_data['hour+direction+x+y'] = df_data['hour'].astype('str') +df_data['direction'].astype('str') + df_data['x'].astype('str') + df_data['y'].astype('str')
df_data['hour+x'] = df_data['hour'].astype('str') + df_data['x'].astype('str')
df_data['hour+y'] = df_data['hour'].astype('str') + df_data['y'].astype('str')
# cycling
from math import sin, cos, pi, exp
sin_vals = {
    'NB': 0.0,
    'NE': sin(1 * pi/4),
    'EB': 1.0,
    'SE': sin(3 * pi/4),
    'SB': 0.0,
    'SW': sin(5 * pi/4),    
    'WB': -1.0,    
    'NW': sin(7 * pi/4),  
}
cos_vals = {
    'NB': 1.0,
    'NE': cos(1 * pi/4),
    'EB': 0.0,
    'SE': cos(3 * pi/4),
    'SB': -1.0,
    'SW': cos(5 * pi/4),    
    'WB': 0.0,    
    'NW': cos(7 * pi/4),  
}
df_data['sin'] = df_data['direction'].map(sin_vals)
df_data['cos'] = df_data['direction'].map(cos_vals)
# baseline score = -7.20654MAE

# combine direction and location
df_data['roadway'] = df_data.x.astype(str) + df_data.y.astype(str) + df_data.direction.astype(str)

# maths trainsformations
df_data['x_cos_hour'] = df_data.x * df_data.cos * df_data.hour
df_data['y_sen_hour'] = df_data.y * df_data.sin * df_data.hour
df_data = df_data.drop(['x','y','direction'], axis=1)
# # px.box(df_data[df_data.congestion.isnull() == False], x="roadway", y="congestion", color = 'roadway')

# # Mean, median, maximum, minimum congestion per roadway / time
keys = ['roadway','hour', 'minute']
df = df_data.groupby(by=keys).mean().reset_index().set_index(keys)
df['mean congestion'] = df['congestion']
df_data = df_data.merge(df['mean congestion'], how='left', left_on=keys, right_on=keys)

df = df_data.groupby(by=keys).median().reset_index().set_index(keys)
df['median congestion'] = df['congestion']
df_data = df_data.merge(df['median congestion'], how='left', left_on=keys, right_on=keys)

df = df_data.groupby(by=keys).min().reset_index().set_index(keys)
df['min congestion'] = df['congestion']
df_data = df_data.merge(df['min congestion'], how='left', left_on=keys, right_on=keys)

df = df_data.groupby(by=keys).max().reset_index().set_index(keys)
df['max congestion'] = df['congestion']
df_data = df_data.merge(df['max congestion'], how='left', left_on=keys, right_on=keys)

from catboost import CatBoostRegressor
model = CatBoostRegressor(task_type="GPU",devices='0:1', loss_function='MAE', verbose=False)
# mean congestion
X = df_data[df_data.congestion.isnull() == False][['mean congestion']]
y = df_data[df_data.congestion.isnull() == False]['congestion']
model.fit(X, y)
y_preds = model.predict(df_data[['mean congestion']])
df_data['meancongestion_preds'] = y_preds

# from math import *
# # df_data['sin_meancongestion']=df_data.apply(lambda x: sin(x['mean congestion']),axis=1)
# df_data['root_meancongestion']=df_data.apply(lambda x: sqrt(x['mean congestion']),axis=1)
# # df_data['log_meancongestion']=df_data.apply(lambda x: np.log2(x['mean congestion']),axis=1)

# %%
# df_data.head(10)

# %%
# df_data.loc[(df_data['congestion'] >= 20) & (df_data['congestion'] <= 40)]

# %%
# from sklearn.preprocessing import LabelEncoder
# qualitative = [col for col in df_data if df_data[col].dtype == 'object']
# for feature in qualitative:
#     df_data[feature] = LabelEncoder().fit_transform(df_data[feature])
# # !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!memory reduction    
# df_data = reduce_mem_usage(df_data)

# # rely on mutual information remove columns
# #df_data = df_data.drop(['month','minute','is_weekend','day_of_year','cos','sin'],axis=1)
# df_train = df_data[df_data.congestion.isnull() == False]

# df_test = df_data[df_data.congestion.isnull() == True]
# df_test = df_test.drop(['congestion'],axis=1)

# X = df_train.drop('congestion', axis=1)
# y = df_train['congestion']

# %% [markdown]
# ## Mutual Information

# %% [markdown]
# The mutual information (MI) between two quantities is a measure of the extent to which knowledge of one quantity reduces uncertainty about the other. If you knew the value of a feature, how much more confident would you be about the target?

# %%
# # see best parameters by mutial information
# from sklearn.feature_selection import mutual_info_regression
# from sklearn.model_selection import cross_val_score
# from xgboost import XGBRegressor

# def make_mi_scores(X, y):
#     X = X.copy()
#     for colname in X.select_dtypes(["object"]):
#         X[colname], _ = X[colname].factorize()
#     # All discrete features should now have integer dtypes
#     #discrete_features = [pd.api.types.is_integer_dtype(t) for t in X.dtypes]
#     mi_scores = mutual_info_regression(X, y, random_state=0)
#     mi_scores = pd.Series(mi_scores, name="MI Scores", index=X.columns)
#     mi_scores = mi_scores.sort_values(ascending=False)
#     return mi_scores

# y = df_data[df_data['congestion'].isnull() == False]['congestion']
# x = df_data[df_data['congestion'].isnull() == False].drop('congestion', axis=1)
# mi_scores = make_mi_scores(x, y)
# mi_scores = pd.DataFrame(mi_scores).reset_index().rename(columns={'index':'Feature'})

# %%
# fig = px.bar(mi_scores, x='MI Scores', y='Feature', color="MI Scores",
#              color_continuous_scale='darkmint')
# fig.update_layout(height = 750, title_text="Mutual Information Scores",
#                   title_font=dict(size=29, family="Lato, sans-serif"), xaxis={'categoryorder':'category ascending'}, margin=dict(t=80))

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
from sklearn.preprocessing import LabelEncoder
qualitative = [col for col in df_data if df_data[col].dtype == 'object']
for feature in qualitative:
    df_data[feature] = LabelEncoder().fit_transform(df_data[feature])
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!memory reduction    
df_data = reduce_mem_usage(df_data)

# rely on mutual information remove columns
df_data = df_data.drop(['is_month_end','minute','is_month_start','month','is_weekend','day_of_year','is_afternoon','hour','hour+minute'], axis=1)


df_train = df_data[df_data.congestion.isnull() == False]
df_test = df_data[df_data.congestion.isnull() == True]
df_test = df_test.drop(['congestion'],axis=1)

X = df_train.drop('congestion', axis=1)
y = df_train['congestion']

# pca
from sklearn.preprocessing import StandardScaler 
train_standard = StandardScaler().fit_transform(X)
train_standard = pd.DataFrame(train_standard, index=X.index, columns=X.columns)
from sklearn.decomposition import PCA
pca = PCA(n_components=6)
principalComponents = pca.fit_transform(train_standard)
#principalDf = pd.DataFrame(data = principalComponents, columns = ['pc1', 'pc2', 'pc3', 'pc4', 'pc5', 'pc6', 'pc7', 'pc8', 'pc9', 'pc10'])
X = pd.DataFrame(data = principalComponents, columns = ['pc1', 'pc2', 'pc3', 'pc4', 'pc5', 'pc6'])

# pca
train_standard = StandardScaler().fit_transform(df_test)
train_standard = pd.DataFrame(train_standard, index=df_test.index, columns=df_test.columns)
pca = PCA(n_components=6)
principalComponents = pca.fit_transform(train_standard)
#principalDf = pd.DataFrame(data = principalComponents, columns = ['pc1', 'pc2', 'pc3', 'pc4', 'pc5', 'pc6', 'pc7', 'pc8', 'pc9', 'pc10'])
df_test = pd.DataFrame(data = principalComponents, columns = ['pc1', 'pc2', 'pc3', 'pc4', 'pc5','pc6'])
# Out:
# Mem. usage decreased to 60.07 Mb (59.8% reduction)

# %%
print(np.cumsum((pca.explained_variance_ratio_)))
# Out:
# [0.3769244  0.5925313  0.7494953  0.85841274 0.93913513 0.97160125]

# %% [markdown]
# # Hyperparameters Tuning

# %%
def scikit_grid():
    from sklearn.model_selection import GridSearchCV
    from catboost import CatBoostRegressor
    parameters = {'depth'         : [4,6,10],
                     'learning_rate' : [0.01,0.05],
                      'iterations'    : [500, 1000, 1500]
                     }
    CBC = CatBoostRegressor(task_type="GPU",devices='0:1', loss_function='MAE', verbose=True)
    Grid_CBC = GridSearchCV(estimator=CBC, param_grid = parameters, cv = 3)

    Grid_CBC.fit(X, y)

    # print("\n The best score across ALL searched params:\n",Grid_CBC.best_score_)
    print("\n The best parameters across ALL searched params:\n",Grid_CBC.best_params_)
    
# def catboost_grid():
#     from catboost import CatBoostRegressor
#     param_grid = {'depth'         : [4,6,10],
#                      'learning_rate' : [0.01,0.04],
#                       'iterations'    : [500, 1000]
#                      }
#     model =  CatBoostRegressor(task_type="GPU",devices='0:1', loss_function='MAE')
#     model.grid_search(param_grid,
#             X,
#             y,
#             cv=3,
#             #search_by_train_test_split=True,
#             shuffle=True,
#             verbose=False,
#             plot=True)
    
scikit_grid()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Modeling

# %%
from catboost import CatBoostRegressor
model = CatBoostRegressor(task_type="GPU",devices='0:1', loss_function='MAE', verbose=True)
model.fit(X, y)
y_preds = model.predict(df_test)
# Out:
# Custom logger is already specified. Specify more than one logger at same time is not thread safe.
# 0:	learn: 13.5944229	total: 39.6ms	remaining: 39.6s
# 1:	learn: 13.3210600	total: 76.9ms	remaining: 38.4s
# 2:	learn: 13.0656606	total: 114ms	remaining: 38s
# 3:	learn: 12.8193866	total: 152ms	remaining: 37.9s
# 4:	learn: 12.5846566	total: 197ms	remaining: 39.3s
# 5:	learn: 12.3523853	total: 244ms	remaining: 40.4s
# 6:	learn: 12.1286575	total: 288ms	remaining: 40.9s
# 7:	learn: 11.9151684	total: 327ms	remaining: 40.6s
# 8:	learn: 11.7074402	total: 367ms	remaining: 40.4s
# 9:	learn: 11.5054775	total: 405ms	remaining: 40.1s
# 10:	learn: 11.3130879	total: 443ms	remaining: 39.8s
# 11:	learn: 11.1270482	total: 485ms	remaining: 39.9s
# 12:	learn: 10.9475092	total: 527ms	remaining: 40s
# 13:	learn: 10.7798866	total: 566ms	remaining: 39.9s
# 14:	learn: 10.6152138	total: 604ms	remaining: 39.7s
# 15:	learn: 10.4580125	total: 642ms	remaining: 39.5s
# 16:	learn: 10.3070090	total: 681ms	remaining: 39.4s
# 17:	learn: 10.1640437	total: 724ms	remaining: 39.5s
# 18:	learn: 10.0243934	total: 762ms	remaining: 39.4s
# 19:	learn: 9.8905924	total: 800ms	remaining: 39.2s
# 20:	learn: 9.7674972	total: 839ms	remaining: 39.1s
# 21:	learn: 9.6437541	total: 878ms	remaining: 39s
# 22:	learn: 9.5259685	total: 917ms	remaining: 38.9s
# 23:	learn: 9.4135521	total: 957ms	remaining: 38.9s
# 24:	learn: 9.3055835	total: 995ms	remaining: 38.8s
# 25:	learn: 9.2003570	total: 1.03s	remaining: 38.7s
# 26:	learn: 9.0999281	total: 1.07s	remaining: 38.7s
# 27:	learn: 9.0040049	total: 1.11s	remaining: 38.6s
# 28:	learn: 8.9138890	total: 1.15s	remaining: 38.5s
# 29:	learn: 8.8278087	total: 1.19s	remaining: 38.5s
# 30:	learn: 8.7430714	total: 1.23s	remaining: 38.4s
# 31:	learn: 8.6635335	total: 1.27s	remaining: 38.3s
# 32:	learn: 8.5877974	total: 1.3s	remaining: 38.3s
# 33:	learn: 8.5149098	total: 1.34s	remaining: 38.2s
# 34:	learn: 8.4469791	total: 1.38s	remaining: 38.1s
# 35:	learn: 8.3808013	total: 1.42s	remaining: 38.2s
# 36:	learn: 8.3173520	total: 1.46s	remaining: 38.1s
# 37:	learn: 8.2553989	total: 1.5s	remaining: 38s
# 38:	learn: 8.1989715	total: 1.54s	remaining: 38s
# 39:	learn: 8.1424158	total: 1.58s	remaining: 37.9s
# 40:	learn: 8.0877514	total: 1.62s	remaining: 37.9s
# 41:	learn: 8.0366220	total: 1.66s	remaining: 37.9s
# 42:	learn: 7.9898160	total: 1.7s	remaining: 37.9s
# 43:	learn: 7.9438754	total: 1.74s	remaining: 37.8s
# 44:	learn: 7.8985380	total: 1.78s	remaining: 37.8s
# 45:	learn: 7.8546160	total: 1.82s	remaining: 37.7s
# 46:	learn: 7.8131627	total: 1.86s	remaining: 37.7s
# 47:	learn: 7.7728021	total: 1.9s	remaining: 37.6s
# 48:	learn: 7.7350798	total: 1.94s	remaining: 37.6s
# 49:	learn: 7.6982441	total: 1.98s	remaining: 37.5s
# 50:	learn: 7.6639806	total: 2.01s	remaining: 37.5s
# 51:	learn: 7.6293985	total: 2.05s	remaining: 37.4s
# 52:	learn: 7.5965140	total: 2.09s	remaining: 37.4s
# 53:	learn: 7.5648371	total: 2.13s	remaining: 37.4s
# 54:	learn: 7.5370714	total: 2.17s	remaining: 37.4s
# 55:	learn: 7.5079185	total: 2.21s	remaining: 37.3s
# 56:	learn: 7.4810234	total: 2.25s	remaining: 37.3s
# 57:	learn: 7.4551061	total: 2.29s	remaining: 37.2s
# 58:	learn: 7.4298615	total: 2.33s	remaining: 37.2s
# 59:	learn: 7.4061508	total: 2.37s	remaining: 37.2s
# 60:	learn: 7.3829525	total: 2.41s	remaining: 37.1s
# 61:	learn: 7.3614424	total: 2.45s	remaining: 37.1s
# 62:	learn: 7.3412937	total: 2.49s	remaining: 37.1s
# 63:	learn: 7.3214783	total: 2.53s	remaining: 37s
# 64:	learn: 7.3021135	total: 2.57s	remaining: 37s
# 65:	learn: 7.2834208	total: 2.61s	remaining: 37s
# 66:	learn: 7.2657825	total: 2.65s	remaining: 36.9s
# 67:	learn: 7.2483469	total: 2.69s	remaining: 36.9s
# 68:	learn: 7.2319520	total: 2.73s	remaining: 36.8s
# 69:	learn: 7.2162517	total: 2.77s	remaining: 36.8s
# 70:	learn: 7.2019209	total: 2.81s	remaining: 36.8s
# 71:	learn: 7.1873756	total: 2.85s	remaining: 36.8s
# 72:	learn: 7.1731014	total: 2.89s	remaining: 36.7s
# 73:	learn: 7.1594939	total: 2.93s	remaining: 36.7s
# 74:	learn: 7.1465161	total: 2.97s	remaining: 36.7s
# 75:	learn: 7.1335348	total: 3.01s	remaining: 36.6s
# 76:	learn: 7.1211219	total: 3.05s	remaining: 36.6s
# 77:	learn: 7.1095684	total: 3.1s	remaining: 36.6s
# 78:	learn: 7.0986670	total: 3.13s	remaining: 36.6s
# 79:	learn: 7.0877037	total: 3.17s	remaining: 36.5s
# 80:	learn: 7.0771475	total: 3.21s	remaining: 36.5s
# 81:	learn: 7.0670101	total: 3.25s	remaining: 36.4s
# 82:	learn: 7.0576926	total: 3.29s	remaining: 36.4s
# 83:	learn: 7.0481972	total: 3.33s	remaining: 36.3s
# 84:	learn: 7.0395118	total: 3.37s	remaining: 36.3s
# 85:	learn: 7.0312416	total: 3.41s	remaining: 36.3s
# 86:	learn: 7.0226575	total: 3.45s	remaining: 36.2s
# 87:	learn: 7.0147661	total: 3.49s	remaining: 36.2s
# 88:	learn: 7.0068747	total: 3.53s	remaining: 36.2s
# 89:	learn: 7.0003764	total: 3.57s	remaining: 36.1s
# 90:	learn: 6.9933314	total: 3.62s	remaining: 36.1s
# 91:	learn: 6.9861398	total: 3.65s	remaining: 36.1s
# 92:	learn: 6.9796721	total: 3.69s	remaining: 36s
# 93:	learn: 6.9735113	total: 3.73s	remaining: 36s
# 94:	learn: 6.9673529	total: 3.78s	remaining: 36s
# 95:	learn: 6.9616362	total: 3.82s	remaining: 36s
# 96:	learn: 6.9568379	total: 3.86s	remaining: 35.9s
# 97:	learn: 6.9513315	total: 3.9s	remaining: 35.9s
# 98:	learn: 6.9461662	total: 3.94s	remaining: 35.9s
# 99:	learn: 6.9415823	total: 3.98s	remaining: 35.8s
# 100:	learn: 6.9371810	total: 4.02s	remaining: 35.8s
# 101:	learn: 6.9330747	total: 4.06s	remaining: 35.7s
# 102:	learn: 6.9283371	total: 4.1s	remaining: 35.7s
# 103:	learn: 6.9232672	total: 4.14s	remaining: 35.7s
# 104:	learn: 6.9191751	total: 4.18s	remaining: 35.6s
# 105:	learn: 6.9152827	total: 4.22s	remaining: 35.6s
# 106:	learn: 6.9114168	total: 4.26s	remaining: 35.5s
# 107:	learn: 6.9077318	total: 4.3s	remaining: 35.5s
# 108:	learn: 6.9045527	total: 4.34s	remaining: 35.5s
# 109:	learn: 6.9014897	total: 4.38s	remaining: 35.5s
# 110:	learn: 6.8981310	total: 4.42s	remaining: 35.4s
# 111:	learn: 6.8947128	total: 4.46s	remaining: 35.4s
# 112:	learn: 6.8911408	total: 4.51s	remaining: 35.4s
# 113:	learn: 6.8882021	total: 4.55s	remaining: 35.4s
# 114:	learn: 6.8851703	total: 4.59s	remaining: 35.3s
# 115:	learn: 6.8825031	total: 4.63s	remaining: 35.3s
# 116:	learn: 6.8797387	total: 4.67s	remaining: 35.3s
# 117:	learn: 6.8769337	total: 4.72s	remaining: 35.3s
# 118:	learn: 6.8744573	total: 4.76s	remaining: 35.2s
# 119:	learn: 6.8717466	total: 4.8s	remaining: 35.2s
# 120:	learn: 6.8693015	total: 4.84s	remaining: 35.2s
# 121:	learn: 6.8668557	total: 4.88s	remaining: 35.1s
# 122:	learn: 6.8644648	total: 4.92s	remaining: 35.1s
# 123:	learn: 6.8619602	total: 4.96s	remaining: 35.1s
# 124:	learn: 6.8596865	total: 5.01s	remaining: 35.1s
# 125:	learn: 6.8574069	total: 5.05s	remaining: 35s
# 126:	learn: 6.8553140	total: 5.09s	remaining: 35s
# 127:	learn: 6.8530044	total: 5.13s	remaining: 34.9s
# 128:	learn: 6.8510623	total: 5.17s	remaining: 34.9s
# 129:	learn: 6.8493347	total: 5.21s	remaining: 34.9s
# 130:	learn: 6.8474338	total: 5.25s	remaining: 34.8s
# 131:	learn: 6.8456962	total: 5.29s	remaining: 34.8s
# 132:	learn: 6.8441069	total: 5.33s	remaining: 34.8s
# 133:	learn: 6.8422208	total: 5.37s	remaining: 34.7s
# 134:	learn: 6.8406298	total: 5.41s	remaining: 34.7s
# 135:	learn: 6.8387631	total: 5.46s	remaining: 34.7s
# 136:	learn: 6.8371179	total: 5.5s	remaining: 34.6s
# 137:	learn: 6.8355623	total: 5.54s	remaining: 34.6s
# 138:	learn: 6.8339895	total: 5.58s	remaining: 34.5s
# 139:	learn: 6.8320899	total: 5.61s	remaining: 34.5s
# 140:	learn: 6.8304888	total: 5.66s	remaining: 34.5s
# 141:	learn: 6.8288619	total: 5.7s	remaining: 34.4s
# 142:	learn: 6.8272715	total: 5.74s	remaining: 34.4s
# 143:	learn: 6.8258407	total: 5.78s	remaining: 34.3s
# 144:	learn: 6.8243599	total: 5.82s	remaining: 34.3s
# 145:	learn: 6.8229691	total: 5.86s	remaining: 34.3s
# 146:	learn: 6.8215519	total: 5.89s	remaining: 34.2s
# 147:	learn: 6.8199827	total: 5.94s	remaining: 34.2s
# 148:	learn: 6.8186243	total: 5.98s	remaining: 34.1s
# 149:	learn: 6.8169562	total: 6.02s	remaining: 34.1s
# 150:	learn: 6.8155124	total: 6.05s	remaining: 34s
# 151:	learn: 6.8140434	total: 6.09s	remaining: 34s
# 152:	learn: 6.8126738	total: 6.14s	remaining: 34s
# 153:	learn: 6.8115205	total: 6.18s	remaining: 34s
# 154:	learn: 6.8101651	total: 6.22s	remaining: 33.9s
# 155:	learn: 6.8087555	total: 6.26s	remaining: 33.9s
# 156:	learn: 6.8076752	total: 6.3s	remaining: 33.8s
# 157:	learn: 6.8066450	total: 6.34s	remaining: 33.8s
# 158:	learn: 6.8054922	total: 6.38s	remaining: 33.8s
# 159:	learn: 6.8042252	total: 6.42s	remaining: 33.7s
# 160:	learn: 6.8032062	total: 6.46s	remaining: 33.7s
# 161:	learn: 6.8017654	total: 6.5s	remaining: 33.6s
# 162:	learn: 6.8007339	total: 6.54s	remaining: 33.6s
# 163:	learn: 6.7995347	total: 6.59s	remaining: 33.6s
# 164:	learn: 6.7984756	total: 6.63s	remaining: 33.5s
# 165:	learn: 6.7977110	total: 6.67s	remaining: 33.5s
# 166:	learn: 6.7966372	total: 6.71s	remaining: 33.5s
# 167:	learn: 6.7957866	total: 6.75s	remaining: 33.5s
# 168:	learn: 6.7949201	total: 6.8s	remaining: 33.4s
# 169:	learn: 6.7940136	total: 6.84s	remaining: 33.4s
# 170:	learn: 6.7929097	total: 6.88s	remaining: 33.3s
# 171:	learn: 6.7921121	total: 6.92s	remaining: 33.3s
# 172:	learn: 6.7912616	total: 6.96s	remaining: 33.3s
# 173:	learn: 6.7906454	total: 7.01s	remaining: 33.3s
# 174:	learn: 6.7897448	total: 7.04s	remaining: 33.2s
# 175:	learn: 6.7887622	total: 7.08s	remaining: 33.2s
# 176:	learn: 6.7879240	total: 7.13s	remaining: 33.1s
# 177:	learn: 6.7874404	total: 7.17s	remaining: 33.1s
# 178:	learn: 6.7867819	total: 7.21s	remaining: 33.1s
# 179:	learn: 6.7857840	total: 7.25s	remaining: 33s
# 180:	learn: 6.7851167	total: 7.29s	remaining: 33s
# 181:	learn: 6.7840605	total: 7.33s	remaining: 32.9s
# 182:	learn: 6.7832924	total: 7.37s	remaining: 32.9s
# 183:	learn: 6.7828589	total: 7.42s	remaining: 32.9s
# 184:	learn: 6.7821037	total: 7.45s	remaining: 32.8s
# 185:	learn: 6.7814446	total: 7.5s	remaining: 32.8s
# 186:	learn: 6.7807996	total: 7.54s	remaining: 32.8s
# 187:	learn: 6.7800727	total: 7.58s	remaining: 32.7s
# 188:	learn: 6.7793364	total: 7.62s	remaining: 32.7s
# 189:	learn: 6.7787662	total: 7.66s	remaining: 32.7s
# 190:	learn: 6.7779027	total: 7.7s	remaining: 32.6s
# 191:	learn: 6.7773101	total: 7.75s	remaining: 32.6s
# 192:	learn: 6.7766981	total: 7.79s	remaining: 32.6s
# 193:	learn: 6.7761249	total: 7.82s	remaining: 32.5s
# 194:	learn: 6.7755971	total: 7.87s	remaining: 32.5s
# 195:	learn: 6.7750923	total: 7.91s	remaining: 32.4s
# 196:	learn: 6.7743655	total: 7.95s	remaining: 32.4s
# 197:	learn: 6.7737735	total: 7.99s	remaining: 32.3s
# 198:	learn: 6.7731803	total: 8.02s	remaining: 32.3s
# 199:	learn: 6.7725100	total: 8.06s	remaining: 32.3s
# 200:	learn: 6.7719675	total: 8.11s	remaining: 32.2s
# 201:	learn: 6.7715251	total: 8.14s	remaining: 32.2s
# 202:	learn: 6.7709084	total: 8.18s	remaining: 32.1s
# 203:	learn: 6.7702769	total: 8.22s	remaining: 32.1s
# 204:	learn: 6.7699199	total: 8.26s	remaining: 32.1s
# 205:	learn: 6.7692885	total: 8.3s	remaining: 32s
# 206:	learn: 6.7686759	total: 8.35s	remaining: 32s
# 207:	learn: 6.7682282	total: 8.39s	remaining: 31.9s
# 208:	learn: 6.7677181	total: 8.43s	remaining: 31.9s
# 209:	learn: 6.7672581	total: 8.46s	remaining: 31.8s
# 210:	learn: 6.7667580	total: 8.5s	remaining: 31.8s
# 211:	learn: 6.7663250	total: 8.54s	remaining: 31.8s
# 212:	learn: 6.7659033	total: 8.59s	remaining: 31.7s
# 213:	learn: 6.7653879	total: 8.63s	remaining: 31.7s
# 214:	learn: 6.7648989	total: 8.66s	remaining: 31.6s
# 215:	learn: 6.7645049	total: 8.7s	remaining: 31.6s
# 216:	learn: 6.7641073	total: 8.74s	remaining: 31.6s
# 217:	learn: 6.7636296	total: 8.78s	remaining: 31.5s
# 218:	learn: 6.7632331	total: 8.83s	remaining: 31.5s
# 219:	learn: 6.7627006	total: 8.87s	remaining: 31.4s
# 220:	learn: 6.7620698	total: 8.91s	remaining: 31.4s
# 221:	learn: 6.7617063	total: 8.95s	remaining: 31.4s
# 222:	learn: 6.7612651	total: 8.99s	remaining: 31.3s
# 223:	learn: 6.7606867	total: 9.03s	remaining: 31.3s
# 224:	learn: 6.7603203	total: 9.07s	remaining: 31.3s
# 225:	learn: 6.7599245	total: 9.12s	remaining: 31.2s
# 226:	learn: 6.7596624	total: 9.16s	remaining: 31.2s
# 227:	learn: 6.7593943	total: 9.2s	remaining: 31.1s
# 228:	learn: 6.7592070	total: 9.25s	remaining: 31.1s
# 229:	learn: 6.7588412	total: 9.29s	remaining: 31.1s
# 230:	learn: 6.7586033	total: 9.33s	remaining: 31.1s
# 231:	learn: 6.7582021	total: 9.37s	remaining: 31s
# 232:	learn: 6.7578711	total: 9.41s	remaining: 31s
# 233:	learn: 6.7573404	total: 9.46s	remaining: 31s
# 234:	learn: 6.7570900	total: 9.5s	remaining: 30.9s
# 235:	learn: 6.7566294	total: 9.54s	remaining: 30.9s
# 236:	learn: 6.7561711	total: 9.58s	remaining: 30.8s
# 237:	learn: 6.7557535	total: 9.62s	remaining: 30.8s
# 238:	learn: 6.7551362	total: 9.67s	remaining: 30.8s
# 239:	learn: 6.7548128	total: 9.71s	remaining: 30.7s
# 240:	learn: 6.7543027	total: 9.75s	remaining: 30.7s
# 241:	learn: 6.7538992	total: 9.79s	remaining: 30.7s
# 242:	learn: 6.7535357	total: 9.83s	remaining: 30.6s
# 243:	learn: 6.7530185	total: 9.87s	remaining: 30.6s
# 244:	learn: 6.7526575	total: 9.91s	remaining: 30.6s
# 245:	learn: 6.7523571	total: 9.96s	remaining: 30.5s
# 246:	learn: 6.7518246	total: 10s	remaining: 30.5s
# 247:	learn: 6.7514411	total: 10s	remaining: 30.4s
# 248:	learn: 6.7510229	total: 10.1s	remaining: 30.4s
# 249:	learn: 6.7507873	total: 10.1s	remaining: 30.4s
# 250:	learn: 6.7505952	total: 10.2s	remaining: 30.3s
# 251:	learn: 6.7503814	total: 10.2s	remaining: 30.3s
# 252:	learn: 6.7502012	total: 10.2s	remaining: 30.2s
# 253:	learn: 6.7498283	total: 10.3s	remaining: 30.2s
# 254:	learn: 6.7495944	total: 10.3s	remaining: 30.2s
# 255:	learn: 6.7492705	total: 10.4s	remaining: 30.1s
# 256:	learn: 6.7490372	total: 10.4s	remaining: 30.1s
# 257:	learn: 6.7487692	total: 10.4s	remaining: 30s
# 258:	learn: 6.7485613	total: 10.5s	remaining: 30s
# 259:	learn: 6.7482797	total: 10.5s	remaining: 30s
# 260:	learn: 6.7480788	total: 10.6s	remaining: 29.9s
# 261:	learn: 6.7478856	total: 10.6s	remaining: 29.9s
# 262:	learn: 6.7476153	total: 10.7s	remaining: 29.8s
# 263:	learn: 6.7472989	total: 10.7s	remaining: 29.8s
# 264:	learn: 6.7470616	total: 10.7s	remaining: 29.8s
# 265:	learn: 6.7468100	total: 10.8s	remaining: 29.7s
# 266:	learn: 6.7463983	total: 10.8s	remaining: 29.7s
# 267:	learn: 6.7461591	total: 10.9s	remaining: 29.6s
# 268:	learn: 6.7459836	total: 10.9s	remaining: 29.6s
# 269:	learn: 6.7457763	total: 10.9s	remaining: 29.6s
# 270:	learn: 6.7455683	total: 11s	remaining: 29.5s
# 271:	learn: 6.7454323	total: 11s	remaining: 29.5s
# 272:	learn: 6.7451807	total: 11.1s	remaining: 29.5s
# 273:	learn: 6.7448568	total: 11.1s	remaining: 29.4s
# 274:	learn: 6.7443461	total: 11.1s	remaining: 29.4s
# 275:	learn: 6.7440580	total: 11.2s	remaining: 29.4s
# 276:	learn: 6.7435986	total: 11.2s	remaining: 29.3s
# 277:	learn: 6.7433565	total: 11.3s	remaining: 29.3s
# 278:	learn: 6.7430567	total: 11.3s	remaining: 29.2s
# 279:	learn: 6.7427292	total: 11.4s	remaining: 29.2s
# 280:	learn: 6.7425053	total: 11.4s	remaining: 29.2s
# 281:	learn: 6.7422473	total: 11.4s	remaining: 29.1s
# 282:	learn: 6.7418974	total: 11.5s	remaining: 29.1s
# 283:	learn: 6.7417095	total: 11.5s	remaining: 29.1s
# 284:	learn: 6.7411888	total: 11.6s	remaining: 29s
# 285:	learn: 6.7408371	total: 11.6s	remaining: 29s
# 286:	learn: 6.7406693	total: 11.6s	remaining: 28.9s
# 287:	learn: 6.7404325	total: 11.7s	remaining: 28.9s
# 288:	learn: 6.7399589	total: 11.7s	remaining: 28.9s
# 289:	learn: 6.7397362	total: 11.8s	remaining: 28.8s
# 290:	learn: 6.7395253	total: 11.8s	remaining: 28.8s
# 291:	learn: 6.7393339	total: 11.8s	remaining: 28.7s
# 292:	learn: 6.7390200	total: 11.9s	remaining: 28.7s
# 293:	learn: 6.7386889	total: 11.9s	remaining: 28.7s
# 294:	learn: 6.7382990	total: 12s	remaining: 28.6s
# 295:	learn: 6.7380757	total: 12s	remaining: 28.6s
# 296:	learn: 6.7378389	total: 12.1s	remaining: 28.5s
# 297:	learn: 6.7375096	total: 12.1s	remaining: 28.5s
# 298:	learn: 6.7371380	total: 12.1s	remaining: 28.5s
# 299:	learn: 6.7367074	total: 12.2s	remaining: 28.4s
# 300:	learn: 6.7362138	total: 12.2s	remaining: 28.4s
# 301:	learn: 6.7357914	total: 12.3s	remaining: 28.3s
# 302:	learn: 6.7355422	total: 12.3s	remaining: 28.3s
# 303:	learn: 6.7352672	total: 12.3s	remaining: 28.3s
# 304:	learn: 6.7348625	total: 12.4s	remaining: 28.2s
# 305:	learn: 6.7344902	total: 12.4s	remaining: 28.2s
# 306:	learn: 6.7342010	total: 12.5s	remaining: 28.1s
# 307:	learn: 6.7338753	total: 12.5s	remaining: 28.1s
# 308:	learn: 6.7335371	total: 12.5s	remaining: 28s
# 309:	learn: 6.7332079	total: 12.6s	remaining: 28s
# 310:	learn: 6.7328821	total: 12.6s	remaining: 28s
# 311:	learn: 6.7326336	total: 12.7s	remaining: 27.9s
# 312:	learn: 6.7323473	total: 12.7s	remaining: 27.9s
# 313:	learn: 6.7319915	total: 12.7s	remaining: 27.8s
# 314:	learn: 6.7317364	total: 12.8s	remaining: 27.8s
# 315:	learn: 6.7315450	total: 12.8s	remaining: 27.8s
# 316:	learn: 6.7312846	total: 12.9s	remaining: 27.7s
# 317:	learn: 6.7311333	total: 12.9s	remaining: 27.7s
# 318:	learn: 6.7309171	total: 13s	remaining: 27.7s
# 319:	learn: 6.7302827	total: 13s	remaining: 27.6s
# 320:	learn: 6.7299852	total: 13s	remaining: 27.6s
# 321:	learn: 6.7298315	total: 13.1s	remaining: 27.5s
# 322:	learn: 6.7296724	total: 13.1s	remaining: 27.5s
# 323:	learn: 6.7295340	total: 13.2s	remaining: 27.5s
# 324:	learn: 6.7293956	total: 13.2s	remaining: 27.4s
# 325:	learn: 6.7292713	total: 13.2s	remaining: 27.4s
# 326:	learn: 6.7291476	total: 13.3s	remaining: 27.3s
# 327:	learn: 6.7290321	total: 13.3s	remaining: 27.3s
# 328:	learn: 6.7288843	total: 13.4s	remaining: 27.3s
# 329:	learn: 6.7287506	total: 13.4s	remaining: 27.2s
# 330:	learn: 6.7286198	total: 13.4s	remaining: 27.2s
# 331:	learn: 6.7284926	total: 13.5s	remaining: 27.1s
# 332:	learn: 6.7284001	total: 13.5s	remaining: 27.1s
# 333:	learn: 6.7282852	total: 13.6s	remaining: 27s
# 334:	learn: 6.7282181	total: 13.6s	remaining: 27s
# 335:	learn: 6.7281062	total: 13.6s	remaining: 27s
# 336:	learn: 6.7279954	total: 13.7s	remaining: 26.9s
# 337:	learn: 6.7278299	total: 13.7s	remaining: 26.9s
# 338:	learn: 6.7277198	total: 13.8s	remaining: 26.8s
# 339:	learn: 6.7276249	total: 13.8s	remaining: 26.8s
# 340:	learn: 6.7275548	total: 13.8s	remaining: 26.8s
# 341:	learn: 6.7275030	total: 13.9s	remaining: 26.7s
# 342:	learn: 6.7274600	total: 13.9s	remaining: 26.7s
# 343:	learn: 6.7273958	total: 14s	remaining: 26.6s
# 344:	learn: 6.7272974	total: 14s	remaining: 26.6s
# 345:	learn: 6.7272332	total: 14.1s	remaining: 26.6s
# 346:	learn: 6.7270954	total: 14.1s	remaining: 26.5s
# 347:	learn: 6.7270082	total: 14.1s	remaining: 26.5s
# 348:	learn: 6.7269522	total: 14.2s	remaining: 26.4s
# 349:	learn: 6.7268927	total: 14.2s	remaining: 26.4s
# 350:	learn: 6.7267714	total: 14.3s	remaining: 26.4s
# 351:	learn: 6.7266701	total: 14.3s	remaining: 26.3s
# 352:	learn: 6.7265676	total: 14.3s	remaining: 26.3s
# 353:	learn: 6.7265128	total: 14.4s	remaining: 26.2s
# 354:	learn: 6.7264622	total: 14.4s	remaining: 26.2s
# 355:	learn: 6.7263496	total: 14.5s	remaining: 26.2s
# 356:	learn: 6.7262395	total: 14.5s	remaining: 26.1s
# 357:	learn: 6.7261983	total: 14.5s	remaining: 26.1s
# 358:	learn: 6.7260981	total: 14.6s	remaining: 26s
# 359:	learn: 6.7260616	total: 14.6s	remaining: 26s
# 360:	learn: 6.7260233	total: 14.7s	remaining: 26s
# 361:	learn: 6.7259768	total: 14.7s	remaining: 25.9s
# 362:	learn: 6.7259320	total: 14.7s	remaining: 25.9s
# 363:	learn: 6.7258513	total: 14.8s	remaining: 25.8s
# 364:	learn: 6.7258048	total: 14.8s	remaining: 25.8s
# 365:	learn: 6.7257653	total: 14.9s	remaining: 25.8s
# 366:	learn: 6.7257418	total: 14.9s	remaining: 25.7s
# 367:	learn: 6.7256581	total: 15s	remaining: 25.7s
# 368:	learn: 6.7255756	total: 15s	remaining: 25.6s
# 369:	learn: 6.7255391	total: 15s	remaining: 25.6s
# 370:	learn: 6.7255144	total: 15.1s	remaining: 25.6s
# 371:	learn: 6.7254843	total: 15.1s	remaining: 25.5s
# 372:	learn: 6.7254484	total: 15.2s	remaining: 25.5s
# 373:	learn: 6.7253235	total: 15.2s	remaining: 25.4s
# 374:	learn: 6.7252234	total: 15.2s	remaining: 25.4s
# 375:	learn: 6.7251704	total: 15.3s	remaining: 25.4s
# 376:	learn: 6.7251415	total: 15.3s	remaining: 25.3s
# 377:	learn: 6.7250914	total: 15.4s	remaining: 25.3s
# 378:	learn: 6.7250484	total: 15.4s	remaining: 25.3s
# 379:	learn: 6.7250149	total: 15.5s	remaining: 25.2s
# 380:	learn: 6.7249937	total: 15.5s	remaining: 25.2s
# 381:	learn: 6.7248287	total: 15.5s	remaining: 25.1s
# 382:	learn: 6.7247068	total: 15.6s	remaining: 25.1s
# 383:	learn: 6.7246014	total: 15.6s	remaining: 25.1s
# 384:	learn: 6.7244859	total: 15.7s	remaining: 25s
# 385:	learn: 6.7243705	total: 15.7s	remaining: 25s
# 386:	learn: 6.7242644	total: 15.8s	remaining: 24.9s
# 387:	learn: 6.7241784	total: 15.8s	remaining: 24.9s
# 388:	learn: 6.7241030	total: 15.8s	remaining: 24.9s
# 389:	learn: 6.7240070	total: 15.9s	remaining: 24.8s
# 390:	learn: 6.7239210	total: 15.9s	remaining: 24.8s
# 391:	learn: 6.7238427	total: 16s	remaining: 24.8s
# 392:	learn: 6.7237908	total: 16s	remaining: 24.7s
# 393:	learn: 6.7237013	total: 16s	remaining: 24.7s
# 394:	learn: 6.7236118	total: 16.1s	remaining: 24.6s
# 395:	learn: 6.7235782	total: 16.1s	remaining: 24.6s
# 396:	learn: 6.7235093	total: 16.2s	remaining: 24.6s
# 397:	learn: 6.7234893	total: 16.2s	remaining: 24.5s
# 398:	learn: 6.7233791	total: 16.2s	remaining: 24.5s
# 399:	learn: 6.7233320	total: 16.3s	remaining: 24.4s
# 400:	learn: 6.7231564	total: 16.3s	remaining: 24.4s
# 401:	learn: 6.7230799	total: 16.4s	remaining: 24.4s
# 402:	learn: 6.7230068	total: 16.4s	remaining: 24.3s
# 403:	learn: 6.7229055	total: 16.5s	remaining: 24.3s
# 404:	learn: 6.7228283	total: 16.5s	remaining: 24.2s
# 405:	learn: 6.7227618	total: 16.5s	remaining: 24.2s
# 406:	learn: 6.7226940	total: 16.6s	remaining: 24.2s
# 407:	learn: 6.7226469	total: 16.6s	remaining: 24.1s
# 408:	learn: 6.7225662	total: 16.7s	remaining: 24.1s
# 409:	learn: 6.7225026	total: 16.7s	remaining: 24s
# 410:	learn: 6.7224384	total: 16.7s	remaining: 24s
# 411:	learn: 6.7223889	total: 16.8s	remaining: 24s
# 412:	learn: 6.7223023	total: 16.8s	remaining: 23.9s
# 413:	learn: 6.7222193	total: 16.9s	remaining: 23.9s
# 414:	learn: 6.7221551	total: 16.9s	remaining: 23.8s
# 415:	learn: 6.7220767	total: 17s	remaining: 23.8s
# 416:	learn: 6.7220119	total: 17s	remaining: 23.8s
# 417:	learn: 6.7219424	total: 17s	remaining: 23.7s
# 418:	learn: 6.7218753	total: 17.1s	remaining: 23.7s
# 419:	learn: 6.7218234	total: 17.1s	remaining: 23.6s
# 420:	learn: 6.7217804	total: 17.2s	remaining: 23.6s
# 421:	learn: 6.7217251	total: 17.2s	remaining: 23.6s
# 422:	learn: 6.7216721	total: 17.3s	remaining: 23.5s
# 423:	learn: 6.7216102	total: 17.3s	remaining: 23.5s
# 424:	learn: 6.7215436	total: 17.3s	remaining: 23.4s
# 425:	learn: 6.7214842	total: 17.4s	remaining: 23.4s
# 426:	learn: 6.7214394	total: 17.4s	remaining: 23.4s
# 427:	learn: 6.7213958	total: 17.5s	remaining: 23.3s
# 428:	learn: 6.7213504	total: 17.5s	remaining: 23.3s
# 429:	learn: 6.7213157	total: 17.5s	remaining: 23.3s
# 430:	learn: 6.7212686	total: 17.6s	remaining: 23.2s
# 431:	learn: 6.7212350	total: 17.6s	remaining: 23.2s
# 432:	learn: 6.7211672	total: 17.7s	remaining: 23.1s
# 433:	learn: 6.7211266	total: 17.7s	remaining: 23.1s
# 434:	learn: 6.7210948	total: 17.8s	remaining: 23.1s
# 435:	learn: 6.7210612	total: 17.8s	remaining: 23s
# 436:	learn: 6.7210282	total: 17.8s	remaining: 23s
# 437:	learn: 6.7209899	total: 17.9s	remaining: 22.9s
# 438:	learn: 6.7209575	total: 17.9s	remaining: 22.9s
# 439:	learn: 6.7209310	total: 18s	remaining: 22.9s
# 440:	learn: 6.7209034	total: 18s	remaining: 22.8s
# 441:	learn: 6.7208757	total: 18s	remaining: 22.8s
# 442:	learn: 6.7208509	total: 18.1s	remaining: 22.7s
# 443:	learn: 6.7208221	total: 18.1s	remaining: 22.7s
# 444:	learn: 6.7202619	total: 18.2s	remaining: 22.7s
# 445:	learn: 6.7201553	total: 18.2s	remaining: 22.6s
# 446:	learn: 6.7200345	total: 18.3s	remaining: 22.6s
# 447:	learn: 6.7199632	total: 18.3s	remaining: 22.5s
# 448:	learn: 6.7198172	total: 18.3s	remaining: 22.5s
# 449:	learn: 6.7196587	total: 18.4s	remaining: 22.5s
# 450:	learn: 6.7195079	total: 18.4s	remaining: 22.4s
# 451:	learn: 6.7193730	total: 18.5s	remaining: 22.4s
# 452:	learn: 6.7193477	total: 18.5s	remaining: 22.3s
# 453:	learn: 6.7192923	total: 18.5s	remaining: 22.3s
# 454:	learn: 6.7192635	total: 18.6s	remaining: 22.3s
# 455:	learn: 6.7192352	total: 18.6s	remaining: 22.2s
# 456:	learn: 6.7192122	total: 18.7s	remaining: 22.2s
# 457:	learn: 6.7191916	total: 18.7s	remaining: 22.1s
# 458:	learn: 6.7191415	total: 18.8s	remaining: 22.1s
# 459:	learn: 6.7190932	total: 18.8s	remaining: 22.1s
# 460:	learn: 6.7190644	total: 18.8s	remaining: 22s
# 461:	learn: 6.7190437	total: 18.9s	remaining: 22s
# 462:	learn: 6.7190060	total: 18.9s	remaining: 21.9s
# 463:	learn: 6.7188641	total: 19s	remaining: 21.9s
# 464:	learn: 6.7188452	total: 19s	remaining: 21.9s
# 465:	learn: 6.7188246	total: 19.1s	remaining: 21.8s
# 466:	learn: 6.7188046	total: 19.1s	remaining: 21.8s
# 467:	learn: 6.7187828	total: 19.1s	remaining: 21.8s
# 468:	learn: 6.7187675	total: 19.2s	remaining: 21.7s
# 469:	learn: 6.7187534	total: 19.2s	remaining: 21.7s
# 470:	learn: 6.7187127	total: 19.3s	remaining: 21.6s
# 471:	learn: 6.7186408	total: 19.3s	remaining: 21.6s
# 472:	learn: 6.7184618	total: 19.3s	remaining: 21.6s
# 473:	learn: 6.7182762	total: 19.4s	remaining: 21.5s
# 474:	learn: 6.7181319	total: 19.4s	remaining: 21.5s
# 475:	learn: 6.7179328	total: 19.5s	remaining: 21.4s
# 476:	learn: 6.7177985	total: 19.5s	remaining: 21.4s
# 477:	learn: 6.7175264	total: 19.5s	remaining: 21.3s
# 478:	learn: 6.7173720	total: 19.6s	remaining: 21.3s
# 479:	learn: 6.7172389	total: 19.6s	remaining: 21.3s
# 480:	learn: 6.7170734	total: 19.7s	remaining: 21.2s
# 481:	learn: 6.7169415	total: 19.7s	remaining: 21.2s
# 482:	learn: 6.7168719	total: 19.8s	remaining: 21.1s
# 483:	learn: 6.7167883	total: 19.8s	remaining: 21.1s
# 484:	learn: 6.7167323	total: 19.8s	remaining: 21.1s
# 485:	learn: 6.7166652	total: 19.9s	remaining: 21s
# 486:	learn: 6.7165898	total: 19.9s	remaining: 21s
# 487:	learn: 6.7164826	total: 20s	remaining: 20.9s
# 488:	learn: 6.7163660	total: 20s	remaining: 20.9s
# 489:	learn: 6.7162370	total: 20s	remaining: 20.9s
# 490:	learn: 6.7161298	total: 20.1s	remaining: 20.8s
# 491:	learn: 6.7160119	total: 20.1s	remaining: 20.8s
# 492:	learn: 6.7158523	total: 20.2s	remaining: 20.7s
# 493:	learn: 6.7157404	total: 20.2s	remaining: 20.7s
# 494:	learn: 6.7156379	total: 20.2s	remaining: 20.7s
# 495:	learn: 6.7154942	total: 20.3s	remaining: 20.6s
# 496:	learn: 6.7153404	total: 20.3s	remaining: 20.6s
# 497:	learn: 6.7152220	total: 20.4s	remaining: 20.5s
# 498:	learn: 6.7150783	total: 20.4s	remaining: 20.5s
# 499:	learn: 6.7148227	total: 20.5s	remaining: 20.5s
# 500:	learn: 6.7146919	total: 20.5s	remaining: 20.4s
# 501:	learn: 6.7145823	total: 20.5s	remaining: 20.4s
# 502:	learn: 6.7144763	total: 20.6s	remaining: 20.3s
# 503:	learn: 6.7143667	total: 20.6s	remaining: 20.3s
# 504:	learn: 6.7142501	total: 20.7s	remaining: 20.3s
# 505:	learn: 6.7140116	total: 20.7s	remaining: 20.2s
# 506:	learn: 6.7139638	total: 20.7s	remaining: 20.2s
# 507:	learn: 6.7138684	total: 20.8s	remaining: 20.1s
# 508:	learn: 6.7137783	total: 20.8s	remaining: 20.1s
# 509:	learn: 6.7136858	total: 20.9s	remaining: 20.1s
# 510:	learn: 6.7136004	total: 20.9s	remaining: 20s
# 511:	learn: 6.7134243	total: 21s	remaining: 20s
# 512:	learn: 6.7134072	total: 21s	remaining: 19.9s
# 513:	learn: 6.7133984	total: 21s	remaining: 19.9s
# 514:	learn: 6.7132876	total: 21.1s	remaining: 19.8s
# 515:	learn: 6.7129990	total: 21.1s	remaining: 19.8s
# 516:	learn: 6.7129831	total: 21.1s	remaining: 19.8s
# 517:	learn: 6.7129701	total: 21.2s	remaining: 19.7s
# 518:	learn: 6.7129519	total: 21.2s	remaining: 19.7s
# 519:	learn: 6.7129383	total: 21.3s	remaining: 19.6s
# 520:	learn: 6.7129254	total: 21.3s	remaining: 19.6s
# 521:	learn: 6.7129077	total: 21.4s	remaining: 19.6s
# 522:	learn: 6.7128947	total: 21.4s	remaining: 19.5s
# 523:	learn: 6.7128765	total: 21.4s	remaining: 19.5s
# 524:	learn: 6.7128547	total: 21.5s	remaining: 19.4s
# 525:	learn: 6.7128358	total: 21.5s	remaining: 19.4s
# 526:	learn: 6.7127858	total: 21.6s	remaining: 19.4s
# 527:	learn: 6.7127675	total: 21.6s	remaining: 19.3s
# 528:	learn: 6.7126585	total: 21.7s	remaining: 19.3s
# 529:	learn: 6.7125331	total: 21.7s	remaining: 19.3s
# 530:	learn: 6.7124806	total: 21.8s	remaining: 19.3s
# 531:	learn: 6.7124600	total: 21.9s	remaining: 19.2s
# 532:	learn: 6.7124441	total: 21.9s	remaining: 19.2s
# 533:	learn: 6.7123505	total: 21.9s	remaining: 19.1s
# 534:	learn: 6.7122809	total: 22s	remaining: 19.1s
# 535:	learn: 6.7122203	total: 22s	remaining: 19.1s
# 536:	learn: 6.7121679	total: 22.1s	remaining: 19s
# 537:	learn: 6.7120777	total: 22.1s	remaining: 19s
# 538:	learn: 6.7118822	total: 22.2s	remaining: 18.9s
# 539:	learn: 6.7118627	total: 22.2s	remaining: 18.9s
# 540:	learn: 6.7118350	total: 22.2s	remaining: 18.9s
# 541:	learn: 6.7118256	total: 22.3s	remaining: 18.8s
# 542:	learn: 6.7117856	total: 22.3s	remaining: 18.8s
# 543:	learn: 6.7117443	total: 22.4s	remaining: 18.7s
# 544:	learn: 6.7116960	total: 22.4s	remaining: 18.7s
# 545:	learn: 6.7116483	total: 22.5s	remaining: 18.7s
# 546:	learn: 6.7116200	total: 22.5s	remaining: 18.6s
# 547:	learn: 6.7116100	total: 22.6s	remaining: 18.6s
# 548:	learn: 6.7115847	total: 22.6s	remaining: 18.6s
# 549:	learn: 6.7115099	total: 22.6s	remaining: 18.5s
# 550:	learn: 6.7114333	total: 22.7s	remaining: 18.5s
# 551:	learn: 6.7113685	total: 22.7s	remaining: 18.5s
# 552:	learn: 6.7113043	total: 22.8s	remaining: 18.4s
# 553:	learn: 6.7112301	total: 22.8s	remaining: 18.4s
# 554:	learn: 6.7111700	total: 22.9s	remaining: 18.3s
# 555:	learn: 6.7111571	total: 22.9s	remaining: 18.3s
# 556:	learn: 6.7110716	total: 22.9s	remaining: 18.2s
# 557:	learn: 6.7110593	total: 23s	remaining: 18.2s
# 558:	learn: 6.7110487	total: 23s	remaining: 18.2s
# 559:	learn: 6.7110392	total: 23.1s	remaining: 18.1s
# 560:	learn: 6.7110292	total: 23.1s	remaining: 18.1s
# 561:	learn: 6.7110204	total: 23.2s	remaining: 18s
# 562:	learn: 6.7109550	total: 23.2s	remaining: 18s
# 563:	learn: 6.7109415	total: 23.2s	remaining: 18s
# 564:	learn: 6.7109332	total: 23.3s	remaining: 17.9s
# 565:	learn: 6.7109232	total: 23.3s	remaining: 17.9s
# 566:	learn: 6.7109132	total: 23.4s	remaining: 17.8s
# 567:	learn: 6.7109026	total: 23.4s	remaining: 17.8s
# 568:	learn: 6.7108985	total: 23.5s	remaining: 17.8s
# 569:	learn: 6.7108855	total: 23.5s	remaining: 17.7s
# 570:	learn: 6.7108796	total: 23.5s	remaining: 17.7s
# 571:	learn: 6.7108354	total: 23.6s	remaining: 17.6s
# 572:	learn: 6.7108089	total: 23.6s	remaining: 17.6s
# 573:	learn: 6.7107223	total: 23.7s	remaining: 17.6s
# 574:	learn: 6.7106517	total: 23.7s	remaining: 17.5s
# 575:	learn: 6.7105757	total: 23.7s	remaining: 17.5s
# 576:	learn: 6.7105073	total: 23.8s	remaining: 17.4s
# 577:	learn: 6.7103937	total: 23.8s	remaining: 17.4s
# 578:	learn: 6.7103200	total: 23.9s	remaining: 17.4s
# 579:	learn: 6.7102081	total: 23.9s	remaining: 17.3s
# 580:	learn: 6.7101769	total: 24s	remaining: 17.3s
# 581:	learn: 6.7101227	total: 24s	remaining: 17.3s
# 582:	learn: 6.7100444	total: 24.1s	remaining: 17.2s
# 583:	learn: 6.7099955	total: 24.1s	remaining: 17.2s
# 584:	learn: 6.7099177	total: 24.2s	remaining: 17.2s
# 585:	learn: 6.7098771	total: 24.2s	remaining: 17.1s
# 586:	learn: 6.7098400	total: 24.3s	remaining: 17.1s
# 587:	learn: 6.7098252	total: 24.3s	remaining: 17.1s
# 588:	learn: 6.7097887	total: 24.4s	remaining: 17s
# 589:	learn: 6.7097581	total: 24.4s	remaining: 17s
# 590:	learn: 6.7097221	total: 24.5s	remaining: 16.9s
# 591:	learn: 6.7096880	total: 24.5s	remaining: 16.9s
# 592:	learn: 6.7096791	total: 24.6s	remaining: 16.9s
# 593:	learn: 6.7096485	total: 24.6s	remaining: 16.8s
# 594:	learn: 6.7096179	total: 24.7s	remaining: 16.8s
# 595:	learn: 6.7095849	total: 24.7s	remaining: 16.8s
# 596:	learn: 6.7095602	total: 24.8s	remaining: 16.7s
# 597:	learn: 6.7095390	total: 24.8s	remaining: 16.7s
# 598:	learn: 6.7095113	total: 24.9s	remaining: 16.7s
# 599:	learn: 6.7094671	total: 24.9s	remaining: 16.6s
# 600:	learn: 6.7094429	total: 25s	remaining: 16.6s
# 601:	learn: 6.7094064	total: 25s	remaining: 16.5s
# 602:	learn: 6.7093817	total: 25.1s	remaining: 16.5s
# 603:	learn: 6.7093634	total: 25.1s	remaining: 16.5s
# 604:	learn: 6.7093463	total: 25.1s	remaining: 16.4s
# 605:	learn: 6.7093293	total: 25.2s	remaining: 16.4s
# 606:	learn: 6.7093134	total: 25.2s	remaining: 16.3s
# 607:	learn: 6.7092733	total: 25.3s	remaining: 16.3s
# 608:	learn: 6.7092562	total: 25.3s	remaining: 16.2s
# 609:	learn: 6.7092427	total: 25.3s	remaining: 16.2s
# 610:	learn: 6.7092303	total: 25.4s	remaining: 16.2s
# 611:	learn: 6.7092179	total: 25.4s	remaining: 16.1s
# 612:	learn: 6.7092073	total: 25.5s	remaining: 16.1s
# 613:	learn: 6.7092026	total: 25.5s	remaining: 16s
# 614:	learn: 6.7091908	total: 25.6s	remaining: 16s
# 615:	learn: 6.7091826	total: 25.6s	remaining: 16s
# 616:	learn: 6.7091196	total: 25.7s	remaining: 15.9s
# 617:	learn: 6.7091095	total: 25.7s	remaining: 15.9s
# 618:	learn: 6.7090577	total: 25.8s	remaining: 15.9s
# 619:	learn: 6.7090518	total: 25.8s	remaining: 15.8s
# 620:	learn: 6.7090447	total: 25.9s	remaining: 15.8s
# 621:	learn: 6.7090383	total: 25.9s	remaining: 15.7s
# 622:	learn: 6.7090324	total: 25.9s	remaining: 15.7s
# 623:	learn: 6.7090283	total: 26s	remaining: 15.7s
# 624:	learn: 6.7089929	total: 26s	remaining: 15.6s
# 625:	learn: 6.7089570	total: 26.1s	remaining: 15.6s
# 626:	learn: 6.7089234	total: 26.1s	remaining: 15.5s
# 627:	learn: 6.7088863	total: 26.1s	remaining: 15.5s
# 628:	learn: 6.7088368	total: 26.2s	remaining: 15.4s
# 629:	learn: 6.7088138	total: 26.2s	remaining: 15.4s
# 630:	learn: 6.7087231	total: 26.2s	remaining: 15.3s
# 631:	learn: 6.7086713	total: 26.3s	remaining: 15.3s
# 632:	learn: 6.7086206	total: 26.3s	remaining: 15.3s
# 633:	learn: 6.7085953	total: 26.4s	remaining: 15.2s
# 634:	learn: 6.7085706	total: 26.4s	remaining: 15.2s
# 635:	learn: 6.7085376	total: 26.4s	remaining: 15.1s
# 636:	learn: 6.7085081	total: 26.5s	remaining: 15.1s
# 637:	learn: 6.7084669	total: 26.5s	remaining: 15s
# 638:	learn: 6.7084192	total: 26.6s	remaining: 15s
# 639:	learn: 6.7083727	total: 26.6s	remaining: 15s
# 640:	learn: 6.7082920	total: 26.6s	remaining: 14.9s
# 641:	learn: 6.7082808	total: 26.7s	remaining: 14.9s
# 642:	learn: 6.7081582	total: 26.7s	remaining: 14.8s
# 643:	learn: 6.7081170	total: 26.8s	remaining: 14.8s
# 644:	learn: 6.7080770	total: 26.8s	remaining: 14.8s
# 645:	learn: 6.7080410	total: 26.8s	remaining: 14.7s
# 646:	learn: 6.7078319	total: 26.9s	remaining: 14.7s
# 647:	learn: 6.7078190	total: 26.9s	remaining: 14.6s
# 648:	learn: 6.7078048	total: 27s	remaining: 14.6s
# 649:	learn: 6.7077430	total: 27s	remaining: 14.6s
# 650:	learn: 6.7076829	total: 27.1s	remaining: 14.5s
# 651:	learn: 6.7076204	total: 27.1s	remaining: 14.5s
# 652:	learn: 6.7076063	total: 27.2s	remaining: 14.4s
# 653:	learn: 6.7075986	total: 27.2s	remaining: 14.4s
# 654:	learn: 6.7075144	total: 27.3s	remaining: 14.4s
# 655:	learn: 6.7074785	total: 27.3s	remaining: 14.3s
# 656:	learn: 6.7074620	total: 27.4s	remaining: 14.3s
# 657:	learn: 6.7074567	total: 27.4s	remaining: 14.2s
# 658:	learn: 6.7074537	total: 27.4s	remaining: 14.2s
# 659:	learn: 6.7074490	total: 27.5s	remaining: 14.2s
# 660:	learn: 6.7074449	total: 27.5s	remaining: 14.1s
# 661:	learn: 6.7074367	total: 27.6s	remaining: 14.1s
# 662:	learn: 6.7074343	total: 27.6s	remaining: 14s
# 663:	learn: 6.7074249	total: 27.6s	remaining: 14s
# 664:	learn: 6.7074172	total: 27.7s	remaining: 13.9s
# 665:	learn: 6.7073719	total: 27.7s	remaining: 13.9s
# 666:	learn: 6.7073359	total: 27.8s	remaining: 13.9s
# 667:	learn: 6.7073035	total: 27.8s	remaining: 13.8s
# 668:	learn: 6.7072982	total: 27.8s	remaining: 13.8s
# 669:	learn: 6.7072823	total: 27.9s	remaining: 13.7s
# 670:	learn: 6.7072647	total: 27.9s	remaining: 13.7s
# 671:	learn: 6.7072552	total: 28s	remaining: 13.7s
# 672:	learn: 6.7072299	total: 28s	remaining: 13.6s
# 673:	learn: 6.7071981	total: 28.1s	remaining: 13.6s
# 674:	learn: 6.7071686	total: 28.1s	remaining: 13.5s
# 675:	learn: 6.7071186	total: 28.1s	remaining: 13.5s
# 676:	learn: 6.7070826	total: 28.2s	remaining: 13.4s
# 677:	learn: 6.7070709	total: 28.2s	remaining: 13.4s
# 678:	learn: 6.7070620	total: 28.3s	remaining: 13.4s
# 679:	learn: 6.7070532	total: 28.3s	remaining: 13.3s
# 680:	learn: 6.7070426	total: 28.4s	remaining: 13.3s
# 681:	learn: 6.7070143	total: 28.4s	remaining: 13.2s
# 682:	learn: 6.7068706	total: 28.4s	remaining: 13.2s
# 683:	learn: 6.7068435	total: 28.5s	remaining: 13.2s
# 684:	learn: 6.7068176	total: 28.5s	remaining: 13.1s
# 685:	learn: 6.7067993	total: 28.6s	remaining: 13.1s
# 686:	learn: 6.7067634	total: 28.6s	remaining: 13s
# 687:	learn: 6.7067222	total: 28.7s	remaining: 13s
# 688:	learn: 6.7066792	total: 28.7s	remaining: 13s
# 689:	learn: 6.7066415	total: 28.7s	remaining: 12.9s
# 690:	learn: 6.7066144	total: 28.8s	remaining: 12.9s
# 691:	learn: 6.7065714	total: 28.8s	remaining: 12.8s
# 692:	learn: 6.7065148	total: 28.9s	remaining: 12.8s
# 693:	learn: 6.7064889	total: 28.9s	remaining: 12.7s
# 694:	learn: 6.7064359	total: 28.9s	remaining: 12.7s
# 695:	learn: 6.7063935	total: 29s	remaining: 12.7s
# 696:	learn: 6.7063416	total: 29s	remaining: 12.6s
# 697:	learn: 6.7063192	total: 29.1s	remaining: 12.6s
# 698:	learn: 6.7062721	total: 29.1s	remaining: 12.5s
# 699:	learn: 6.7062209	total: 29.1s	remaining: 12.5s
# 700:	learn: 6.7062056	total: 29.2s	remaining: 12.4s
# 701:	learn: 6.7061791	total: 29.2s	remaining: 12.4s
# 702:	learn: 6.7061549	total: 29.3s	remaining: 12.4s
# 703:	learn: 6.7061219	total: 29.3s	remaining: 12.3s
# 704:	learn: 6.7060972	total: 29.4s	remaining: 12.3s
# 705:	learn: 6.7060795	total: 29.4s	remaining: 12.3s
# 706:	learn: 6.7060489	total: 29.5s	remaining: 12.2s
# 707:	learn: 6.7060289	total: 29.5s	remaining: 12.2s
# 708:	learn: 6.7060012	total: 29.5s	remaining: 12.1s
# 709:	learn: 6.7059817	total: 29.6s	remaining: 12.1s
# 710:	learn: 6.7059646	total: 29.6s	remaining: 12s
# 711:	learn: 6.7059281	total: 29.7s	remaining: 12s
# 712:	learn: 6.7059075	total: 29.7s	remaining: 12s
# 713:	learn: 6.7058810	total: 29.7s	remaining: 11.9s
# 714:	learn: 6.7058421	total: 29.8s	remaining: 11.9s
# 715:	learn: 6.7058062	total: 29.8s	remaining: 11.8s
# 716:	learn: 6.7057290	total: 29.9s	remaining: 11.8s
# 717:	learn: 6.7056519	total: 29.9s	remaining: 11.7s
# 718:	learn: 6.7056283	total: 30s	remaining: 11.7s
# 719:	learn: 6.7056212	total: 30s	remaining: 11.7s
# 720:	learn: 6.7056083	total: 30s	remaining: 11.6s
# 721:	learn: 6.7056059	total: 30.1s	remaining: 11.6s
# 722:	learn: 6.7055977	total: 30.1s	remaining: 11.5s
# 723:	learn: 6.7055941	total: 30.2s	remaining: 11.5s
# 724:	learn: 6.7055771	total: 30.2s	remaining: 11.5s
# 725:	learn: 6.7054787	total: 30.3s	remaining: 11.4s
# 726:	learn: 6.7054221	total: 30.3s	remaining: 11.4s
# 727:	learn: 6.7054009	total: 30.4s	remaining: 11.3s
# 728:	learn: 6.7053974	total: 30.4s	remaining: 11.3s
# 729:	learn: 6.7053756	total: 30.5s	remaining: 11.3s
# 730:	learn: 6.7053544	total: 30.5s	remaining: 11.2s
# 731:	learn: 6.7053509	total: 30.5s	remaining: 11.2s
# 732:	learn: 6.7053255	total: 30.6s	remaining: 11.1s
# 733:	learn: 6.7053202	total: 30.6s	remaining: 11.1s
# 734:	learn: 6.7053108	total: 30.7s	remaining: 11.1s
# 735:	learn: 6.7053043	total: 30.7s	remaining: 11s
# 736:	learn: 6.7052967	total: 30.8s	remaining: 11s
# 737:	learn: 6.7052902	total: 30.8s	remaining: 10.9s
# 738:	learn: 6.7052761	total: 30.9s	remaining: 10.9s
# 739:	learn: 6.7052684	total: 30.9s	remaining: 10.9s
# 740:	learn: 6.7052660	total: 30.9s	remaining: 10.8s
# 741:	learn: 6.7052495	total: 31s	remaining: 10.8s
# 742:	learn: 6.7052413	total: 31s	remaining: 10.7s
# 743:	learn: 6.7052372	total: 31.1s	remaining: 10.7s
# 744:	learn: 6.7052260	total: 31.1s	remaining: 10.7s
# 745:	learn: 6.7052177	total: 31.2s	remaining: 10.6s
# 746:	learn: 6.7052160	total: 31.2s	remaining: 10.6s
# 747:	learn: 6.7052018	total: 31.3s	remaining: 10.5s
# 748:	learn: 6.7051936	total: 31.3s	remaining: 10.5s
# 749:	learn: 6.7051795	total: 31.4s	remaining: 10.5s
# 750:	learn: 6.7051659	total: 31.4s	remaining: 10.4s
# 751:	learn: 6.7051541	total: 31.4s	remaining: 10.4s
# 752:	learn: 6.7051376	total: 31.5s	remaining: 10.3s
# 753:	learn: 6.7051306	total: 31.5s	remaining: 10.3s
# 754:	learn: 6.7051270	total: 31.6s	remaining: 10.3s
# 755:	learn: 6.7051147	total: 31.6s	remaining: 10.2s
# 756:	learn: 6.7051176	total: 31.7s	remaining: 10.2s
# 757:	learn: 6.7051035	total: 31.7s	remaining: 10.1s
# 758:	learn: 6.7050999	total: 31.8s	remaining: 10.1s
# 759:	learn: 6.7050870	total: 31.8s	remaining: 10.1s
# 760:	learn: 6.7050746	total: 31.9s	remaining: 10s
# 761:	learn: 6.7050758	total: 31.9s	remaining: 9.97s
# 762:	learn: 6.7050693	total: 32s	remaining: 9.94s
# 763:	learn: 6.7050575	total: 32s	remaining: 9.89s
# 764:	learn: 6.7050552	total: 32.1s	remaining: 9.86s
# 765:	learn: 6.7050440	total: 32.1s	remaining: 9.81s
# 766:	learn: 6.7050375	total: 32.2s	remaining: 9.77s
# 767:	learn: 6.7050340	total: 32.2s	remaining: 9.73s
# 768:	learn: 6.7050116	total: 32.3s	remaining: 9.69s
# 769:	learn: 6.7050116	total: 32.3s	remaining: 9.65s
# 770:	learn: 6.7050039	total: 32.3s	remaining: 9.61s
# 771:	learn: 6.7049621	total: 32.4s	remaining: 9.56s
# 772:	learn: 6.7049456	total: 32.4s	remaining: 9.52s
# 773:	learn: 6.7049055	total: 32.5s	remaining: 9.48s
# 774:	learn: 6.7048678	total: 32.5s	remaining: 9.44s
# 775:	learn: 6.7048231	total: 32.5s	remaining: 9.39s
# 776:	learn: 6.7047777	total: 32.6s	remaining: 9.36s
# 777:	learn: 6.7047371	total: 32.6s	remaining: 9.31s
# 778:	learn: 6.7046970	total: 32.7s	remaining: 9.27s
# 779:	learn: 6.7046104	total: 32.7s	remaining: 9.23s
# 780:	learn: 6.7046069	total: 32.8s	remaining: 9.19s
# 781:	learn: 6.7046022	total: 32.8s	remaining: 9.15s
# 782:	learn: 6.7045922	total: 32.9s	remaining: 9.11s
# 783:	learn: 6.7045775	total: 32.9s	remaining: 9.07s
# 784:	learn: 6.7045392	total: 33s	remaining: 9.03s
# 785:	learn: 6.7045209	total: 33s	remaining: 8.98s
# 786:	learn: 6.7045115	total: 33s	remaining: 8.94s
# 787:	learn: 6.7045003	total: 33.1s	remaining: 8.9s
# 788:	learn: 6.7044638	total: 33.1s	remaining: 8.86s
# 789:	learn: 6.7044508	total: 33.2s	remaining: 8.81s
# 790:	learn: 6.7044361	total: 33.2s	remaining: 8.77s
# 791:	learn: 6.7044284	total: 33.2s	remaining: 8.73s
# 792:	learn: 6.7044149	total: 33.3s	remaining: 8.69s
# 793:	learn: 6.7044037	total: 33.3s	remaining: 8.64s
# 794:	learn: 6.7043925	total: 33.4s	remaining: 8.6s
# 795:	learn: 6.7043778	total: 33.4s	remaining: 8.56s
# 796:	learn: 6.7043648	total: 33.4s	remaining: 8.52s
# 797:	learn: 6.7043507	total: 33.5s	remaining: 8.48s
# 798:	learn: 6.7043124	total: 33.5s	remaining: 8.44s
# 799:	learn: 6.7043000	total: 33.6s	remaining: 8.39s
# 800:	learn: 6.7042664	total: 33.6s	remaining: 8.35s
# 801:	learn: 6.7042529	total: 33.7s	remaining: 8.31s
# 802:	learn: 6.7042435	total: 33.7s	remaining: 8.27s
# 803:	learn: 6.7042370	total: 33.8s	remaining: 8.23s
# 804:	learn: 6.7042299	total: 33.8s	remaining: 8.19s
# 805:	learn: 6.7042258	total: 33.8s	remaining: 8.15s
# 806:	learn: 6.7042122	total: 33.9s	remaining: 8.11s
# 807:	learn: 6.7042052	total: 33.9s	remaining: 8.07s
# 808:	learn: 6.7041963	total: 34s	remaining: 8.02s
# 809:	learn: 6.7041904	total: 34s	remaining: 7.98s
# 810:	learn: 6.7041775	total: 34.1s	remaining: 7.94s
# 811:	learn: 6.7041692	total: 34.1s	remaining: 7.9s
# 812:	learn: 6.7041657	total: 34.2s	remaining: 7.86s
# 813:	learn: 6.7041575	total: 34.2s	remaining: 7.82s
# 814:	learn: 6.7041280	total: 34.2s	remaining: 7.77s
# 815:	learn: 6.7041239	total: 34.3s	remaining: 7.73s
# 816:	learn: 6.7040968	total: 34.3s	remaining: 7.69s
# 817:	learn: 6.7040090	total: 34.4s	remaining: 7.65s
# 818:	learn: 6.7039313	total: 34.4s	remaining: 7.6s
# 819:	learn: 6.7038947	total: 34.4s	remaining: 7.56s
# 820:	learn: 6.7038765	total: 34.5s	remaining: 7.52s
# 821:	learn: 6.7038565	total: 34.5s	remaining: 7.48s
# 822:	learn: 6.7038523	total: 34.6s	remaining: 7.43s
# 823:	learn: 6.7038223	total: 34.6s	remaining: 7.39s
# 824:	learn: 6.7038111	total: 34.7s	remaining: 7.35s
# 825:	learn: 6.7037981	total: 34.7s	remaining: 7.31s
# 826:	learn: 6.7037687	total: 34.7s	remaining: 7.27s
# 827:	learn: 6.7034624	total: 34.8s	remaining: 7.22s
# 828:	learn: 6.7034530	total: 34.8s	remaining: 7.18s
# 829:	learn: 6.7034447	total: 34.9s	remaining: 7.14s
# 830:	learn: 6.7033628	total: 34.9s	remaining: 7.1s
# 831:	learn: 6.7033575	total: 34.9s	remaining: 7.05s
# 832:	learn: 6.7033511	total: 35s	remaining: 7.01s
# 833:	learn: 6.7033369	total: 35s	remaining: 6.97s
# 834:	learn: 6.7033222	total: 35.1s	remaining: 6.93s
# 835:	learn: 6.7033057	total: 35.1s	remaining: 6.89s
# 836:	learn: 6.7032951	total: 35.2s	remaining: 6.85s
# 837:	learn: 6.7032827	total: 35.2s	remaining: 6.8s
# 838:	learn: 6.7032680	total: 35.2s	remaining: 6.76s
# 839:	learn: 6.7032562	total: 35.3s	remaining: 6.72s
# 840:	learn: 6.7032415	total: 35.3s	remaining: 6.68s
# 841:	learn: 6.7032250	total: 35.4s	remaining: 6.64s
# 842:	learn: 6.7032250	total: 35.4s	remaining: 6.59s
# 843:	learn: 6.7032197	total: 35.5s	remaining: 6.55s
# 844:	learn: 6.7032174	total: 35.5s	remaining: 6.51s
# 845:	learn: 6.7032079	total: 35.6s	remaining: 6.47s
# 846:	learn: 6.7031967	total: 35.6s	remaining: 6.43s
# 847:	learn: 6.7031873	total: 35.6s	remaining: 6.39s
# 848:	learn: 6.7031855	total: 35.7s	remaining: 6.35s
# 849:	learn: 6.7031785	total: 35.7s	remaining: 6.31s
# 850:	learn: 6.7031720	total: 35.8s	remaining: 6.27s
# 851:	learn: 6.7031696	total: 35.8s	remaining: 6.22s
# 852:	learn: 6.7031590	total: 35.9s	remaining: 6.18s
# 853:	learn: 6.7031502	total: 35.9s	remaining: 6.14s
# 854:	learn: 6.7031184	total: 36s	remaining: 6.1s
# 855:	learn: 6.7030954	total: 36s	remaining: 6.05s
# 856:	learn: 6.7030942	total: 36s	remaining: 6.01s
# 857:	learn: 6.7030919	total: 36.1s	remaining: 5.97s
# 858:	learn: 6.7030736	total: 36.1s	remaining: 5.93s
# 859:	learn: 6.7030695	total: 36.2s	remaining: 5.88s
# 860:	learn: 6.7030642	total: 36.2s	remaining: 5.84s
# 861:	learn: 6.7029853	total: 36.2s	remaining: 5.8s
# 862:	learn: 6.7029800	total: 36.3s	remaining: 5.76s
# 863:	learn: 6.7029770	total: 36.3s	remaining: 5.71s
# 864:	learn: 6.7029682	total: 36.4s	remaining: 5.67s
# 865:	learn: 6.7029588	total: 36.4s	remaining: 5.63s
# 866:	learn: 6.7029464	total: 36.4s	remaining: 5.59s
# 867:	learn: 6.7029334	total: 36.5s	remaining: 5.55s
# 868:	learn: 6.7029311	total: 36.5s	remaining: 5.51s
# 869:	learn: 6.7029193	total: 36.6s	remaining: 5.47s
# 870:	learn: 6.7028792	total: 36.6s	remaining: 5.43s
# 871:	learn: 6.7028680	total: 36.7s	remaining: 5.38s
# 872:	learn: 6.7028627	total: 36.7s	remaining: 5.34s
# 873:	learn: 6.7028545	total: 36.8s	remaining: 5.3s
# 874:	learn: 6.7028103	total: 36.8s	remaining: 5.26s
# 875:	learn: 6.7027726	total: 36.9s	remaining: 5.22s
# 876:	learn: 6.7027544	total: 36.9s	remaining: 5.17s
# 877:	learn: 6.7027273	total: 36.9s	remaining: 5.13s
# 878:	learn: 6.7026896	total: 37s	remaining: 5.09s
# 879:	learn: 6.7026442	total: 37s	remaining: 5.05s
# 880:	learn: 6.7026089	total: 37.1s	remaining: 5.01s
# 881:	learn: 6.7025741	total: 37.1s	remaining: 4.97s
# 882:	learn: 6.7025723	total: 37.2s	remaining: 4.93s
# 883:	learn: 6.7025665	total: 37.2s	remaining: 4.89s
# 884:	learn: 6.7025641	total: 37.3s	remaining: 4.84s
# 885:	learn: 6.7025199	total: 37.3s	remaining: 4.8s
# 886:	learn: 6.7024893	total: 37.4s	remaining: 4.76s
# 887:	learn: 6.7024557	total: 37.4s	remaining: 4.72s
# 888:	learn: 6.7024227	total: 37.5s	remaining: 4.68s
# 889:	learn: 6.7023915	total: 37.5s	remaining: 4.63s
# 890:	learn: 6.7023821	total: 37.5s	remaining: 4.59s
# 891:	learn: 6.7023762	total: 37.6s	remaining: 4.55s
# 892:	learn: 6.7023697	total: 37.6s	remaining: 4.51s
# 893:	learn: 6.7023644	total: 37.7s	remaining: 4.47s
# 894:	learn: 6.7023538	total: 37.7s	remaining: 4.42s
# 895:	learn: 6.7023520	total: 37.8s	remaining: 4.38s
# 896:	learn: 6.7023520	total: 37.8s	remaining: 4.34s
# 897:	learn: 6.7023491	total: 37.9s	remaining: 4.3s
# 898:	learn: 6.7023344	total: 37.9s	remaining: 4.26s
# 899:	learn: 6.7023043	total: 37.9s	remaining: 4.21s
# 900:	learn: 6.7023055	total: 38s	remaining: 4.17s
# 901:	learn: 6.7022637	total: 38s	remaining: 4.13s
# 902:	learn: 6.7022590	total: 38.1s	remaining: 4.09s
# 903:	learn: 6.7022554	total: 38.1s	remaining: 4.05s
# 904:	learn: 6.7022560	total: 38.2s	remaining: 4s
# 905:	learn: 6.7022572	total: 38.2s	remaining: 3.96s
# 906:	learn: 6.7022496	total: 38.3s	remaining: 3.92s
# 907:	learn: 6.7022501	total: 38.3s	remaining: 3.88s
# 908:	learn: 6.7022419	total: 38.4s	remaining: 3.84s
# 909:	learn: 6.7022360	total: 38.4s	remaining: 3.8s
# 910:	learn: 6.7022307	total: 38.5s	remaining: 3.76s
# 911:	learn: 6.7021677	total: 38.5s	remaining: 3.72s
# 912:	learn: 6.7021547	total: 38.6s	remaining: 3.67s
# 913:	learn: 6.7021482	total: 38.6s	remaining: 3.63s
# 914:	learn: 6.7021418	total: 38.6s	remaining: 3.59s
# 915:	learn: 6.7020664	total: 38.7s	remaining: 3.55s
# 916:	learn: 6.7020027	total: 38.7s	remaining: 3.51s
# 917:	learn: 6.7019503	total: 38.8s	remaining: 3.46s
# 918:	learn: 6.7018567	total: 38.8s	remaining: 3.42s
# 919:	learn: 6.7018390	total: 38.9s	remaining: 3.38s
# 920:	learn: 6.7018207	total: 39s	remaining: 3.34s
# 921:	learn: 6.7017683	total: 39s	remaining: 3.3s
# 922:	learn: 6.7017577	total: 39s	remaining: 3.26s
# 923:	learn: 6.7017518	total: 39.1s	remaining: 3.21s
# 924:	learn: 6.7017442	total: 39.1s	remaining: 3.17s
# 925:	learn: 6.7017383	total: 39.2s	remaining: 3.13s
# 926:	learn: 6.7017118	total: 39.2s	remaining: 3.09s
# 927:	learn: 6.7016970	total: 39.2s	remaining: 3.04s
# 928:	learn: 6.7016870	total: 39.3s	remaining: 3s
# 929:	learn: 6.7016546	total: 39.3s	remaining: 2.96s
# 930:	learn: 6.7016340	total: 39.4s	remaining: 2.92s
# 931:	learn: 6.7016305	total: 39.4s	remaining: 2.88s
# 932:	learn: 6.7016281	total: 39.5s	remaining: 2.83s
# 933:	learn: 6.7015969	total: 39.5s	remaining: 2.79s
# 934:	learn: 6.7015686	total: 39.5s	remaining: 2.75s
# 935:	learn: 6.7015627	total: 39.6s	remaining: 2.71s
# 936:	learn: 6.7015350	total: 39.6s	remaining: 2.66s
# 937:	learn: 6.7015180	total: 39.7s	remaining: 2.62s
# 938:	learn: 6.7014932	total: 39.7s	remaining: 2.58s
# 939:	learn: 6.7014602	total: 39.7s	remaining: 2.54s
# 940:	learn: 6.7014314	total: 39.8s	remaining: 2.49s
# 941:	learn: 6.7014261	total: 39.8s	remaining: 2.45s
# 942:	learn: 6.7014208	total: 39.9s	remaining: 2.41s
# 943:	learn: 6.7014072	total: 39.9s	remaining: 2.37s
# 944:	learn: 6.7013931	total: 40s	remaining: 2.33s
# 945:	learn: 6.7012499	total: 40s	remaining: 2.28s
# 946:	learn: 6.7012282	total: 40.1s	remaining: 2.24s
# 947:	learn: 6.7012181	total: 40.1s	remaining: 2.2s
# 948:	learn: 6.7012022	total: 40.1s	remaining: 2.16s
# 949:	learn: 6.7011928	total: 40.2s	remaining: 2.12s
# 950:	learn: 6.7011869	total: 40.2s	remaining: 2.07s
# 951:	learn: 6.7011645	total: 40.3s	remaining: 2.03s
# 952:	learn: 6.7011604	total: 40.3s	remaining: 1.99s
# 953:	learn: 6.7011557	total: 40.4s	remaining: 1.95s
# 954:	learn: 6.7010467	total: 40.4s	remaining: 1.9s
# 955:	learn: 6.7010167	total: 40.4s	remaining: 1.86s
# 956:	learn: 6.7009872	total: 40.5s	remaining: 1.82s
# 957:	learn: 6.7009672	total: 40.5s	remaining: 1.78s
# 958:	learn: 6.7009637	total: 40.6s	remaining: 1.73s
# 959:	learn: 6.7009607	total: 40.6s	remaining: 1.69s
# 960:	learn: 6.7008977	total: 40.6s	remaining: 1.65s
# 961:	learn: 6.7008895	total: 40.7s	remaining: 1.61s
# 962:	learn: 6.7008842	total: 40.7s	remaining: 1.56s
# 963:	learn: 6.7008741	total: 40.8s	remaining: 1.52s
# 964:	learn: 6.7008435	total: 40.8s	remaining: 1.48s
# 965:	learn: 6.7008441	total: 40.9s	remaining: 1.44s
# 966:	learn: 6.7008423	total: 40.9s	remaining: 1.4s
# 967:	learn: 6.7008406	total: 40.9s	remaining: 1.35s
# 968:	learn: 6.7008323	total: 41s	remaining: 1.31s
# 969:	learn: 6.7008235	total: 41s	remaining: 1.27s
# 970:	learn: 6.7007952	total: 41.1s	remaining: 1.23s
# 971:	learn: 6.7007958	total: 41.1s	remaining: 1.18s
# 972:	learn: 6.7007875	total: 41.1s	remaining: 1.14s
# 973:	learn: 6.7007846	total: 41.2s	remaining: 1.1s
# 974:	learn: 6.7007799	total: 41.2s	remaining: 1.06s
# 975:	learn: 6.7007074	total: 41.3s	remaining: 1.01s
# 976:	learn: 6.7007104	total: 41.3s	remaining: 973ms
# 977:	learn: 6.7007021	total: 41.4s	remaining: 931ms
# 978:	learn: 6.7006697	total: 41.4s	remaining: 888ms
# 979:	learn: 6.7006615	total: 41.5s	remaining: 846ms
# 980:	learn: 6.7006591	total: 41.5s	remaining: 804ms
# 981:	learn: 6.7006491	total: 41.6s	remaining: 762ms
# 982:	learn: 6.7006438	total: 41.6s	remaining: 720ms
# 983:	learn: 6.7006373	total: 41.7s	remaining: 677ms
# 984:	learn: 6.7006297	total: 41.7s	remaining: 635ms
# 985:	learn: 6.7006038	total: 41.7s	remaining: 593ms
# 986:	learn: 6.7005720	total: 41.8s	remaining: 550ms
# 987:	learn: 6.7005720	total: 41.8s	remaining: 508ms
# 988:	learn: 6.7005672	total: 41.9s	remaining: 466ms
# 989:	learn: 6.7005631	total: 41.9s	remaining: 423ms
# 990:	learn: 6.7005625	total: 42s	remaining: 381ms
# 991:	learn: 6.7005513	total: 42s	remaining: 339ms
# 992:	learn: 6.7005508	total: 42s	remaining: 296ms
# 993:	learn: 6.7005502	total: 42.1s	remaining: 254ms
# 994:	learn: 6.7004860	total: 42.1s	remaining: 212ms
# 995:	learn: 6.7004518	total: 42.2s	remaining: 169ms
# 996:	learn: 6.7004494	total: 42.2s	remaining: 127ms
# 997:	learn: 6.7004459	total: 42.3s	remaining: 84.7ms
# 998:	learn: 6.7004453	total: 42.3s	remaining: 42.3ms
# 999:	learn: 6.7004394	total: 42.3s	remaining: 0us

# %%
feature_importance = model.feature_importances_
sorted_idx = np.argsort(feature_importance)
fig = plt.figure(figsize=(12, 6))
plt.barh(range(len(sorted_idx)), feature_importance[sorted_idx], align='center')
plt.yticks(range(len(sorted_idx)), np.array(X.columns)[sorted_idx])
plt.title('Feature Importance')

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sklearn.metrics import mean_absolute_error
from catboost import CatBoostRegressor

y_probs = []
y_probs_final = []

folds = StratifiedKFold(n_splits = 20, shuffle=True)
for fold, (train_id, test_id) in enumerate(folds.split(X, y)):
    print("fold : ", fold + 1, end = ' ')
    # Split data
    X_train = X.iloc[train_id]
    y_train = y.iloc[train_id]
    X_valid = X.iloc[test_id]
    y_valid = y.iloc[test_id]

    # Train RF
    #model =  RandomForestRegressor(n_jobs=-1)
    model = CatBoostRegressor(depth=10,task_type="GPU",devices='0:1', loss_function='MAE', verbose=False)
    model.fit(X_train, y_train)

    # Print validation score to see how it works
    valid_pred = model.predict(X_valid)
    valid_mae = mean_absolute_error(y_valid, valid_pred)
    print( "Validation MAE: ", valid_mae, end = ' ')

    # test
    y_probs.append(model.predict(df_test))
    print(" ")
    
y_probs_final = sum(y_probs) / len(y_probs)

# %%
y_probs

# %%
y_probs_final

# %% [markdown]
# # Submission

# %%
sub.head(2)

# %%
def save_submission(y_pred):  
    #classes = label.inverse_transform(y_pred)
    sub["congestion"] = y_pred
    #assert len(classes) == sub.shape[0]
    assert 2 == sub.shape[1]   
    sub.to_csv("E:/downloads/sample_submission.csv", index=False)
    return sub

save_submission(y_preds).head(3)
